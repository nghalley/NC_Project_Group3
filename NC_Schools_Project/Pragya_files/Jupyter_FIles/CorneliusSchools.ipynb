# %%
import pandas as pd
from pprint import pprint
import requests
import json

# %%
url='https://api.schooldigger.com/v1.2/schools?st=NC&city=Cornelius&page=1&perPage=50&appID=1b789824&appKey=ae269c64511c0d65f57b507e2a200ee2'

# %%
verify = 'cacert.pem'

# %%
schools_response = requests.get(url, verify = verify)
schools_json = schools_response.json()

# %%
schools = pprint(schools_json)
# Out:
# {'numberOfPages': 1,
#  'numberOfSchools': 6,
#  'schoolList': [{'address': {'city': 'Cornelius',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Cornelius/search.aspx',
#                              'html': '11900 Bailey Rd<br />Cornelius, NC 28031',
#                              'latLong': {'latitude': 35.467451,
#                                          'longitude': -80.837951},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': '11900 Bailey Rd',
#                              'zip': '28031',
#                              'zip4': '',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28031/search.aspx'},
#                  'county': {'countyName': 'Mecklenburg',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#                  'district': {'districtID': '3702970',
#                               'districtName': 'Charlotte-Mecklenburg Schools',
#                               'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=02970',
#                               'url': 'https://www.schooldigger.com/go/NC/district/02970/search.aspx'},
#                  'hasBoundary': True,
#                  'highGrade': '8',
#                  'isCharterSchool': 'No',
#                  'isMagnetSchool': 'No',
#                  'isPrivate': False,
#                  'isTitleISchool': 'No',
#                  'isTitleISchoolwideSchool': 'No',
#                  'isVirtualSchool': 'No',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': '6',
#                  'phone': '(980) 343-1068',
#                  'privateCoed': None,
#                  'privateDays': None,
#                  'privateHasLibrary': None,
#                  'privateHours': None,
#                  'privateOrientation': None,
#                  'rankHistory': [{'averageStandardScore': 94.42293,
#                                   'rank': 24,
#                                   'rankLevel': 'Middle',
#                                   'rankOf': 723,
#                                   'rankStars': 5,
#                                   'rankStatewidePercentage': 96.68,
#                                   'year': 2019},
#                                  {'averageStandardScore': 93.39957,
#                                   'rank': 22,
#                                   'rankLevel': 'Middle',
#                                   'rankOf': 691,
#                                   'rankStars': 5,
#                                   'rankStatewidePercentage': 96.82,
#                                   'year': 2018}],
#                  'rankMovement': -2,
#                  'schoolLevel': 'Middle',
#                  'schoolName': 'Bailey Middle',
#                  'schoolYearlyDetails': [{'numberOfStudents': 1666,
#                                           'numberofAfricanAmericanStudents': 133,
#                                           'numberofAsianStudents': 50,
#                                           'numberofHispanicStudents': 200,
#                                           'numberofIndianStudents': 4,
#                                           'numberofPacificIslanderStudents': 4,
#                                           'numberofTwoOrMoreRaceStudents': 42,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 1233,
#                                           'percentFreeDiscLunch': 18.55,
#                                           'percentofAfricanAmericanStudents': 7.98,
#                                           'percentofAsianStudents': 3.0,
#                                           'percentofHispanicStudents': 12.0,
#                                           'percentofIndianStudents': 0.24,
#                                           'percentofPacificIslanderStudents': 0.24,
#                                           'percentofTwoOrMoreRaceStudents': 2.52,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 74.01,
#                                           'pupilTeacherRatio': 20.8,
#                                           'teachersFulltime': 79.9,
#                                           'year': 2017},
#                                          {'numberOfStudents': 1557,
#                                           'numberofAfricanAmericanStudents': 129,
#                                           'numberofAsianStudents': 36,
#                                           'numberofHispanicStudents': 164,
#                                           'numberofIndianStudents': 3,
#                                           'numberofPacificIslanderStudents': 3,
#                                           'numberofTwoOrMoreRaceStudents': 51,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 1171,
#                                           'percentFreeDiscLunch': 18.88,
#                                           'percentofAfricanAmericanStudents': 8.29,
#                                           'percentofAsianStudents': 2.31,
#                                           'percentofHispanicStudents': 10.53,
#                                           'percentofIndianStudents': 0.19,
#                                           'percentofPacificIslanderStudents': 0.19,
#                                           'percentofTwoOrMoreRaceStudents': 3.28,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 75.21,
#                                           'pupilTeacherRatio': 20.2,
#                                           'teachersFulltime': 77.0,
#                                           'year': 2016}],
#                  'schoolid': '370297002870',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/0297002870/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0297002870/search.aspx'},
#                 {'address': {'city': 'Cornelius',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Cornelius/search.aspx',
#                              'html': '21126 Catawba Ave<br />Cornelius, NC '
#                                      '28031',
#                              'latLong': {'latitude': 35.48172,
#                                          'longitude': -80.864216},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': '21126 Catawba Ave',
#                              'zip': '28031',
#                              'zip4': '',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28031/search.aspx'},
#                  'county': {'countyName': 'Mecklenburg',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#                  'district': {'districtID': '3702970',
#                               'districtName': 'Charlotte-Mecklenburg Schools',
#                               'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=02970',
#                               'url': 'https://www.schooldigger.com/go/NC/district/02970/search.aspx'},
#                  'hasBoundary': True,
#                  'highGrade': '5',
#                  'isCharterSchool': 'No',
#                  'isMagnetSchool': 'No',
#                  'isPrivate': False,
#                  'isTitleISchool': 'No',
#                  'isTitleISchoolwideSchool': 'No',
#                  'isVirtualSchool': 'No',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': 'K',
#                  'phone': '(980) 343-3905',
#                  'privateCoed': None,
#                  'privateDays': None,
#                  'privateHasLibrary': None,
#                  'privateHours': None,
#                  'privateOrientation': None,
#                  'rankHistory': [{'averageStandardScore': 79.73041,
#                                   'rank': 232,
#                                   'rankLevel': 'Elementary',
#                                   'rankOf': 1461,
#                                   'rankStars': 4,
#                                   'rankStatewidePercentage': 84.12,
#                                   'year': 2019},
#                                  {'averageStandardScore': 81.80486,
#                                   'rank': 199,
#                                   'rankLevel': 'Elementary',
#                                   'rankOf': 1434,
#                                   'rankStars': 4,
#                                   'rankStatewidePercentage': 86.12,
#                                   'year': 2018}],
#                  'rankMovement': -33,
#                  'schoolLevel': 'Elementary',
#                  'schoolName': 'Cornelius Elementary',
#                  'schoolYearlyDetails': [{'numberOfStudents': 605,
#                                           'numberofAfricanAmericanStudents': 59,
#                                           'numberofAsianStudents': 18,
#                                           'numberofHispanicStudents': 94,
#                                           'numberofIndianStudents': 3,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 14,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 417,
#                                           'percentFreeDiscLunch': 28.76,
#                                           'percentofAfricanAmericanStudents': 9.75,
#                                           'percentofAsianStudents': 2.98,
#                                           'percentofHispanicStudents': 15.54,
#                                           'percentofIndianStudents': 0.5,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 2.31,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 68.93,
#                                           'pupilTeacherRatio': 17.1,
#                                           'teachersFulltime': 35.2,
#                                           'year': 2017},
#                                          {'numberOfStudents': 634,
#                                           'numberofAfricanAmericanStudents': 69,
#                                           'numberofAsianStudents': 23,
#                                           'numberofHispanicStudents': 96,
#                                           'numberofIndianStudents': 3,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 13,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 430,
#                                           'percentFreeDiscLunch': 29.34,
#                                           'percentofAfricanAmericanStudents': 10.88,
#                                           'percentofAsianStudents': 3.63,
#                                           'percentofHispanicStudents': 15.14,
#                                           'percentofIndianStudents': 0.47,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 2.05,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 67.82,
#                                           'pupilTeacherRatio': 18.6,
#                                           'teachersFulltime': 34.0,
#                                           'year': 2016}],
#                  'schoolid': '370297001205',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/0297001205/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0297001205/search.aspx'},
#                 {'address': {'city': 'Cornelius',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Cornelius/search.aspx',
#                              'html': '17301 Statesville Rd<br />Cornelius, NC '
#                                      '28031',
#                              'latLong': {'latitude': 35.452743,
#                                          'longitude': -80.867257},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': '17301 Statesville Rd',
#                              'zip': '28031',
#                              'zip4': '',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28031/search.aspx'},
#                  'county': {'countyName': 'Mecklenburg',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#                  'hasBoundary': False,
#                  'highGrade': '5',
#                  'isCharterSchool': '(n/a)',
#                  'isMagnetSchool': '(n/a)',
#                  'isPrivate': True,
#                  'isTitleISchool': '(n/a)',
#                  'isTitleISchoolwideSchool': '(n/a)',
#                  'isVirtualSchool': '(n/a)',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': 'PK',
#                  'phone': '(704) 892-5601',
#                  'privateCoed': 'Coed',
#                  'privateDays': 176,
#                  'privateHasLibrary': True,
#                  'privateHours': 6.5,
#                  'privateOrientation': 'Christian (no specific denomination)',
#                  'rankHistory': None,
#                  'rankMovement': None,
#                  'schoolLevel': 'Private',
#                  'schoolName': 'Grace Covenant Academy',
#                  'schoolYearlyDetails': [{'numberOfStudents': 167,
#                                           'numberofAfricanAmericanStudents': 2,
#                                           'numberofAsianStudents': 0,
#                                           'numberofHispanicStudents': 2,
#                                           'numberofIndianStudents': 0,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 3,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 123,
#                                           'percentFreeDiscLunch': None,
#                                           'percentofAfricanAmericanStudents': 1.2,
#                                           'percentofAsianStudents': 0.0,
#                                           'percentofHispanicStudents': 1.2,
#                                           'percentofIndianStudents': 0.0,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 1.8,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 73.65,
#                                           'pupilTeacherRatio': 12.2,
#                                           'teachersFulltime': 10.6,
#                                           'year': 2018},
#                                          {'numberOfStudents': 141,
#                                           'numberofAfricanAmericanStudents': 5,
#                                           'numberofAsianStudents': 0,
#                                           'numberofHispanicStudents': 4,
#                                           'numberofIndianStudents': 0,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 3,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 90,
#                                           'percentFreeDiscLunch': None,
#                                           'percentofAfricanAmericanStudents': 3.55,
#                                           'percentofAsianStudents': 0.0,
#                                           'percentofHispanicStudents': 2.84,
#                                           'percentofIndianStudents': 0.0,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 2.13,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 63.83,
#                                           'pupilTeacherRatio': 8.9,
#                                           'teachersFulltime': 11.4,
#                                           'year': 2016}],
#                  'schoolid': '379999933866',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/9999933866/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/9999933866/search.aspx'},
#                 {'address': {'city': 'Cornelius',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Cornelius/search.aspx',
#                              'html': '9611 Westmoreland Rd<br />Cornelius, NC '
#                                      '28031',
#                              'latLong': {'latitude': 35.466507,
#                                          'longitude': -80.868005},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': '9611 Westmoreland Rd',
#                              'zip': '28031',
#                              'zip4': '',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28031/search.aspx'},
#                  'county': {'countyName': 'Mecklenburg',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#                  'district': {'districtID': '3702970',
#                               'districtName': 'Charlotte-Mecklenburg Schools',
#                               'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=02970',
#                               'url': 'https://www.schooldigger.com/go/NC/district/02970/search.aspx'},
#                  'hasBoundary': True,
#                  'highGrade': '5',
#                  'isCharterSchool': 'No',
#                  'isMagnetSchool': 'No',
#                  'isPrivate': False,
#                  'isTitleISchool': 'No',
#                  'isTitleISchoolwideSchool': 'No',
#                  'isVirtualSchool': 'No',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': 'K',
#                  'phone': '(980) 343-1071',
#                  'privateCoed': None,
#                  'privateDays': None,
#                  'privateHasLibrary': None,
#                  'privateHours': None,
#                  'privateOrientation': None,
#                  'rankHistory': [{'averageStandardScore': 86.14046,
#                                   'rank': 151,
#                                   'rankLevel': 'Elementary',
#                                   'rankOf': 1461,
#                                   'rankStars': 4,
#                                   'rankStatewidePercentage': 89.66,
#                                   'year': 2019},
#                                  {'averageStandardScore': 90.33965,
#                                   'rank': 89,
#                                   'rankLevel': 'Elementary',
#                                   'rankOf': 1434,
#                                   'rankStars': 5,
#                                   'rankStatewidePercentage': 93.79,
#                                   'year': 2018}],
#                  'rankMovement': -62,
#                  'schoolLevel': 'Elementary',
#                  'schoolName': 'J.V. Washam Elementary',
#                  'schoolYearlyDetails': [{'numberOfStudents': 1033,
#                                           'numberofAfricanAmericanStudents': 86,
#                                           'numberofAsianStudents': 34,
#                                           'numberofHispanicStudents': 104,
#                                           'numberofIndianStudents': 2,
#                                           'numberofPacificIslanderStudents': 3,
#                                           'numberofTwoOrMoreRaceStudents': 36,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 768,
#                                           'percentFreeDiscLunch': 18.39,
#                                           'percentofAfricanAmericanStudents': 8.33,
#                                           'percentofAsianStudents': 3.29,
#                                           'percentofHispanicStudents': 10.07,
#                                           'percentofIndianStudents': 0.19,
#                                           'percentofPacificIslanderStudents': 0.29,
#                                           'percentofTwoOrMoreRaceStudents': 3.48,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 74.35,
#                                           'pupilTeacherRatio': 20.0,
#                                           'teachersFulltime': 51.5,
#                                           'year': 2017},
#                                          {'numberOfStudents': 985,
#                                           'numberofAfricanAmericanStudents': 86,
#                                           'numberofAsianStudents': 32,
#                                           'numberofHispanicStudents': 80,
#                                           'numberofIndianStudents': 4,
#                                           'numberofPacificIslanderStudents': 2,
#                                           'numberofTwoOrMoreRaceStudents': 25,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 756,
#                                           'percentFreeDiscLunch': 20.0,
#                                           'percentofAfricanAmericanStudents': 8.73,
#                                           'percentofAsianStudents': 3.25,
#                                           'percentofHispanicStudents': 8.12,
#                                           'percentofIndianStudents': 0.41,
#                                           'percentofPacificIslanderStudents': 0.2,
#                                           'percentofTwoOrMoreRaceStudents': 2.54,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 76.75,
#                                           'pupilTeacherRatio': 19.3,
#                                           'teachersFulltime': 51.0,
#                                           'year': 2016}],
#                  'schoolid': '370297002891',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/0297002891/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0297002891/search.aspx'},
#                 {'address': {'city': 'Cornelius',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Cornelius/search.aspx',
#                              'html': '17609 Old Statesville Rd<br />Cornelius, '
#                                      'NC 28031',
#                              'latLong': {'latitude': 35.45164,
#                                          'longitude': -80.843621},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': '17609 Old Statesville Rd',
#                              'zip': '28031',
#                              'zip4': '',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28031/search.aspx'},
#                  'county': {'countyName': 'Mecklenburg',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#                  'district': {'districtID': '3700371',
#                               'districtName': 'Lakeside Charter Academy fka '
#                                               'Thunderbird',
#                               'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=00371',
#                               'url': 'https://www.schooldigger.com/go/NC/district/00371/search.aspx'},
#                  'hasBoundary': False,
#                  'highGrade': '8',
#                  'isCharterSchool': 'Yes',
#                  'isMagnetSchool': 'No',
#                  'isPrivate': False,
#                  'isTitleISchool': 'No',
#                  'isTitleISchoolwideSchool': 'No',
#                  'isVirtualSchool': 'No',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': 'K',
#                  'phone': '(704) 896-9500',
#                  'privateCoed': None,
#                  'privateDays': None,
#                  'privateHasLibrary': None,
#                  'privateHours': None,
#                  'privateOrientation': None,
#                  'rankHistory': [{'averageStandardScore': 27.3605,
#                                   'rank': 1131,
#                                   'rankLevel': 'Elementary',
#                                   'rankOf': 1461,
#                                   'rankStars': 1,
#                                   'rankStatewidePercentage': 22.59,
#                                   'year': 2019},
#                                  {'averageStandardScore': 35.08808,
#                                   'rank': 1004,
#                                   'rankLevel': 'Elementary',
#                                   'rankOf': 1434,
#                                   'rankStars': 2,
#                                   'rankStatewidePercentage': 29.99,
#                                   'year': 2018}],
#                  'rankMovement': -127,
#                  'schoolLevel': 'Elementary',
#                  'schoolName': 'Lakeside Charter Academy',
#                  'schoolYearlyDetails': [{'numberOfStudents': 157,
#                                           'numberofAfricanAmericanStudents': 22,
#                                           'numberofAsianStudents': 8,
#                                           'numberofHispanicStudents': 15,
#                                           'numberofIndianStudents': 0,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 11,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 101,
#                                           'percentFreeDiscLunch': None,
#                                           'percentofAfricanAmericanStudents': 14.01,
#                                           'percentofAsianStudents': 5.1,
#                                           'percentofHispanicStudents': 9.55,
#                                           'percentofIndianStudents': 0.0,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 7.01,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 64.33,
#                                           'pupilTeacherRatio': 8.2,
#                                           'teachersFulltime': 19.0,
#                                           'year': 2017},
#                                          {'numberOfStudents': 499,
#                                           'numberofAfricanAmericanStudents': 21,
#                                           'numberofAsianStudents': 11,
#                                           'numberofHispanicStudents': 41,
#                                           'numberofIndianStudents': 2,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 16,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 408,
#                                           'percentFreeDiscLunch': 0.0,
#                                           'percentofAfricanAmericanStudents': 4.21,
#                                           'percentofAsianStudents': 2.2,
#                                           'percentofHispanicStudents': 8.22,
#                                           'percentofIndianStudents': 0.4,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 3.21,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 81.76,
#                                           'pupilTeacherRatio': 13.8,
#                                           'teachersFulltime': 36.0,
#                                           'year': 2016}],
#                  'schoolid': '370037103335',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/0037103335/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0037103335/search.aspx'},
#                 {'address': {'city': 'Cornelius',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Cornelius/search.aspx',
#                              'html': '12420 Bailey Rd<br />Cornelius, NC 28031',
#                              'latLong': {'latitude': 35.46729,
#                                          'longitude': -80.827491},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': '12420 Bailey Rd',
#                              'zip': '28031',
#                              'zip4': '',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28031/search.aspx'},
#                  'county': {'countyName': 'Mecklenburg',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#                  'district': {'districtID': '3702970',
#                               'districtName': 'Charlotte-Mecklenburg Schools',
#                               'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=02970',
#                               'url': 'https://www.schooldigger.com/go/NC/district/02970/search.aspx'},
#                  'hasBoundary': True,
#                  'highGrade': '12',
#                  'isCharterSchool': 'No',
#                  'isMagnetSchool': 'No',
#                  'isPrivate': False,
#                  'isTitleISchool': 'No',
#                  'isTitleISchoolwideSchool': 'No',
#                  'isVirtualSchool': 'No',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': '9',
#                  'phone': '(980) 344-0514',
#                  'privateCoed': None,
#                  'privateDays': None,
#                  'privateHasLibrary': None,
#                  'privateHours': None,
#                  'privateOrientation': None,
#                  'rankHistory': [{'averageStandardScore': 81.32238,
#                                   'rank': 47,
#                                   'rankLevel': 'High',
#                                   'rankOf': 510,
#                                   'rankStars': 5,
#                                   'rankStatewidePercentage': 90.78,
#                                   'year': 2019},
#                                  {'averageStandardScore': 89.6251,
#                                   'rank': 20,
#                                   'rankLevel': 'High',
#                                   'rankOf': 469,
#                                   'rankStars': 5,
#                                   'rankStatewidePercentage': 95.74,
#                                   'year': 2018}],
#                  'rankMovement': -27,
#                  'schoolLevel': 'High',
#                  'schoolName': 'William Amos Hough High',
#                  'schoolYearlyDetails': [{'numberOfStudents': 2594,
#                                           'numberofAfricanAmericanStudents': 265,
#                                           'numberofAsianStudents': 66,
#                                           'numberofHispanicStudents': 234,
#                                           'numberofIndianStudents': 9,
#                                           'numberofPacificIslanderStudents': 5,
#                                           'numberofTwoOrMoreRaceStudents': 66,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 1949,
#                                           'percentFreeDiscLunch': 14.46,
#                                           'percentofAfricanAmericanStudents': 10.22,
#                                           'percentofAsianStudents': 2.54,
#                                           'percentofHispanicStudents': 9.02,
#                                           'percentofIndianStudents': 0.35,
#                                           'percentofPacificIslanderStudents': 0.19,
#                                           'percentofTwoOrMoreRaceStudents': 2.54,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 75.13,
#                                           'pupilTeacherRatio': 20.1,
#                                           'teachersFulltime': 129.0,
#                                           'year': 2017},
#                                          {'numberOfStudents': 2572,
#                                           'numberofAfricanAmericanStudents': 279,
#                                           'numberofAsianStudents': 66,
#                                           'numberofHispanicStudents': 192,
#                                           'numberofIndianStudents': 13,
#                                           'numberofPacificIslanderStudents': 4,
#                                           'numberofTwoOrMoreRaceStudents': 58,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 1960,
#                                           'percentFreeDiscLunch': 16.8,
#                                           'percentofAfricanAmericanStudents': 10.85,
#                                           'percentofAsianStudents': 2.57,
#                                           'percentofHispanicStudents': 7.47,
#                                           'percentofIndianStudents': 0.51,
#                                           'percentofPacificIslanderStudents': 0.16,
#                                           'percentofTwoOrMoreRaceStudents': 2.26,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 76.21,
#                                           'pupilTeacherRatio': 20.2,
#                                           'teachersFulltime': 127.0,
#                                           'year': 2016}],
#                  'schoolid': '370297003175',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/0297003175/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0297003175/search.aspx'}]}

# %%
range(len(schools_json["schoolList"]))
# Out:
# range(0, 6)

# %%
schoolList = schools_json["schoolList"]
schoolList
# Out:
# [{'schoolid': '370297002870',
#   'schoolName': 'Bailey Middle',
#   'phone': '(980) 343-1068',
#   'url': 'https://www.schooldigger.com/go/NC/schools/0297002870/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0297002870/search.aspx',
#   'address': {'latLong': {'latitude': 35.467451, 'longitude': -80.837951},
#    'street': '11900 Bailey Rd',
#    'city': 'Cornelius',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28031',
#    'zip4': '',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Cornelius/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28031/search.aspx',
#    'html': '11900 Bailey Rd<br />Cornelius, NC 28031'},
#   'lowGrade': '6',
#   'highGrade': '8',
#   'schoolLevel': 'Middle',
#   'isCharterSchool': 'No',
#   'isMagnetSchool': 'No',
#   'isVirtualSchool': 'No',
#   'isTitleISchool': 'No',
#   'isTitleISchoolwideSchool': 'No',
#   'district': {'districtID': '3702970',
#    'districtName': 'Charlotte-Mecklenburg Schools',
#    'url': 'https://www.schooldigger.com/go/NC/district/02970/search.aspx',
#    'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=02970'},
#   'county': {'countyName': 'Mecklenburg',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#   'rankHistory': [{'year': 2019,
#     'rank': 24,
#     'rankOf': 723,
#     'rankStars': 5,
#     'rankLevel': 'Middle',
#     'rankStatewidePercentage': 96.68,
#     'averageStandardScore': 94.42293},
#    {'year': 2018,
#     'rank': 22,
#     'rankOf': 691,
#     'rankStars': 5,
#     'rankLevel': 'Middle',
#     'rankStatewidePercentage': 96.82,
#     'averageStandardScore': 93.39957}],
#   'rankMovement': -2,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2017,
#     'numberOfStudents': 1666,
#     'percentFreeDiscLunch': 18.55,
#     'percentofAfricanAmericanStudents': 7.98,
#     'percentofAsianStudents': 3.0,
#     'percentofHispanicStudents': 12.0,
#     'percentofIndianStudents': 0.24,
#     'percentofPacificIslanderStudents': 0.24,
#     'percentofWhiteStudents': 74.01,
#     'percentofTwoOrMoreRaceStudents': 2.52,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 79.9,
#     'pupilTeacherRatio': 20.8,
#     'numberofAfricanAmericanStudents': 133,
#     'numberofAsianStudents': 50,
#     'numberofHispanicStudents': 200,
#     'numberofIndianStudents': 4,
#     'numberofPacificIslanderStudents': 4,
#     'numberofWhiteStudents': 1233,
#     'numberofTwoOrMoreRaceStudents': 42,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': 2016,
#     'numberOfStudents': 1557,
#     'percentFreeDiscLunch': 18.88,
#     'percentofAfricanAmericanStudents': 8.29,
#     'percentofAsianStudents': 2.31,
#     'percentofHispanicStudents': 10.53,
#     'percentofIndianStudents': 0.19,
#     'percentofPacificIslanderStudents': 0.19,
#     'percentofWhiteStudents': 75.21,
#     'percentofTwoOrMoreRaceStudents': 3.28,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 77.0,
#     'pupilTeacherRatio': 20.2,
#     'numberofAfricanAmericanStudents': 129,
#     'numberofAsianStudents': 36,
#     'numberofHispanicStudents': 164,
#     'numberofIndianStudents': 3,
#     'numberofPacificIslanderStudents': 3,
#     'numberofWhiteStudents': 1171,
#     'numberofTwoOrMoreRaceStudents': 51,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': False,
#   'privateDays': None,
#   'privateHours': None,
#   'privateHasLibrary': None,
#   'privateCoed': None,
#   'privateOrientation': None,
#   'hasBoundary': True},
#  {'schoolid': '370297001205',
#   'schoolName': 'Cornelius Elementary',
#   'phone': '(980) 343-3905',
#   'url': 'https://www.schooldigger.com/go/NC/schools/0297001205/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0297001205/search.aspx',
#   'address': {'latLong': {'latitude': 35.48172, 'longitude': -80.864216},
#    'street': '21126 Catawba Ave',
#    'city': 'Cornelius',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28031',
#    'zip4': '',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Cornelius/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28031/search.aspx',
#    'html': '21126 Catawba Ave<br />Cornelius, NC 28031'},
#   'lowGrade': 'K',
#   'highGrade': '5',
#   'schoolLevel': 'Elementary',
#   'isCharterSchool': 'No',
#   'isMagnetSchool': 'No',
#   'isVirtualSchool': 'No',
#   'isTitleISchool': 'No',
#   'isTitleISchoolwideSchool': 'No',
#   'district': {'districtID': '3702970',
#    'districtName': 'Charlotte-Mecklenburg Schools',
#    'url': 'https://www.schooldigger.com/go/NC/district/02970/search.aspx',
#    'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=02970'},
#   'county': {'countyName': 'Mecklenburg',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#   'rankHistory': [{'year': 2019,
#     'rank': 232,
#     'rankOf': 1461,
#     'rankStars': 4,
#     'rankLevel': 'Elementary',
#     'rankStatewidePercentage': 84.12,
#     'averageStandardScore': 79.73041},
#    {'year': 2018,
#     'rank': 199,
#     'rankOf': 1434,
#     'rankStars': 4,
#     'rankLevel': 'Elementary',
#     'rankStatewidePercentage': 86.12,
#     'averageStandardScore': 81.80486}],
#   'rankMovement': -33,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2017,
#     'numberOfStudents': 605,
#     'percentFreeDiscLunch': 28.76,
#     'percentofAfricanAmericanStudents': 9.75,
#     'percentofAsianStudents': 2.98,
#     'percentofHispanicStudents': 15.54,
#     'percentofIndianStudents': 0.5,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 68.93,
#     'percentofTwoOrMoreRaceStudents': 2.31,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 35.2,
#     'pupilTeacherRatio': 17.1,
#     'numberofAfricanAmericanStudents': 59,
#     'numberofAsianStudents': 18,
#     'numberofHispanicStudents': 94,
#     'numberofIndianStudents': 3,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 417,
#     'numberofTwoOrMoreRaceStudents': 14,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': 2016,
#     'numberOfStudents': 634,
#     'percentFreeDiscLunch': 29.34,
#     'percentofAfricanAmericanStudents': 10.88,
#     'percentofAsianStudents': 3.63,
#     'percentofHispanicStudents': 15.14,
#     'percentofIndianStudents': 0.47,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 67.82,
#     'percentofTwoOrMoreRaceStudents': 2.05,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 34.0,
#     'pupilTeacherRatio': 18.6,
#     'numberofAfricanAmericanStudents': 69,
#     'numberofAsianStudents': 23,
#     'numberofHispanicStudents': 96,
#     'numberofIndianStudents': 3,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 430,
#     'numberofTwoOrMoreRaceStudents': 13,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': False,
#   'privateDays': None,
#   'privateHours': None,
#   'privateHasLibrary': None,
#   'privateCoed': None,
#   'privateOrientation': None,
#   'hasBoundary': True},
#  {'schoolid': '379999933866',
#   'schoolName': 'Grace Covenant Academy',
#   'phone': '(704) 892-5601',
#   'url': 'https://www.schooldigger.com/go/NC/schools/9999933866/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/9999933866/search.aspx',
#   'address': {'latLong': {'latitude': 35.452743, 'longitude': -80.867257},
#    'street': '17301 Statesville Rd',
#    'city': 'Cornelius',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28031',
#    'zip4': '',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Cornelius/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28031/search.aspx',
#    'html': '17301 Statesville Rd<br />Cornelius, NC 28031'},
#   'lowGrade': 'PK',
#   'highGrade': '5',
#   'schoolLevel': 'Private',
#   'isCharterSchool': '(n/a)',
#   'isMagnetSchool': '(n/a)',
#   'isVirtualSchool': '(n/a)',
#   'isTitleISchool': '(n/a)',
#   'isTitleISchoolwideSchool': '(n/a)',
#   'county': {'countyName': 'Mecklenburg',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#   'rankHistory': None,
#   'rankMovement': None,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2018,
#     'numberOfStudents': 167,
#     'percentFreeDiscLunch': None,
#     'percentofAfricanAmericanStudents': 1.2,
#     'percentofAsianStudents': 0.0,
#     'percentofHispanicStudents': 1.2,
#     'percentofIndianStudents': 0.0,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 73.65,
#     'percentofTwoOrMoreRaceStudents': 1.8,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 10.6,
#     'pupilTeacherRatio': 12.2,
#     'numberofAfricanAmericanStudents': 2,
#     'numberofAsianStudents': 0,
#     'numberofHispanicStudents': 2,
#     'numberofIndianStudents': 0,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 123,
#     'numberofTwoOrMoreRaceStudents': 3,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': 2016,
#     'numberOfStudents': 141,
#     'percentFreeDiscLunch': None,
#     'percentofAfricanAmericanStudents': 3.55,
#     'percentofAsianStudents': 0.0,
#     'percentofHispanicStudents': 2.84,
#     'percentofIndianStudents': 0.0,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 63.83,
#     'percentofTwoOrMoreRaceStudents': 2.13,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 11.4,
#     'pupilTeacherRatio': 8.9,
#     'numberofAfricanAmericanStudents': 5,
#     'numberofAsianStudents': 0,
#     'numberofHispanicStudents': 4,
#     'numberofIndianStudents': 0,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 90,
#     'numberofTwoOrMoreRaceStudents': 3,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': True,
#   'privateDays': 176,
#   'privateHours': 6.5,
#   'privateHasLibrary': True,
#   'privateCoed': 'Coed',
#   'privateOrientation': 'Christian (no specific denomination)',
#   'hasBoundary': False},
#  {'schoolid': '370297002891',
#   'schoolName': 'J.V. Washam Elementary',
#   'phone': '(980) 343-1071',
#   'url': 'https://www.schooldigger.com/go/NC/schools/0297002891/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0297002891/search.aspx',
#   'address': {'latLong': {'latitude': 35.466507, 'longitude': -80.868005},
#    'street': '9611 Westmoreland Rd',
#    'city': 'Cornelius',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28031',
#    'zip4': '',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Cornelius/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28031/search.aspx',
#    'html': '9611 Westmoreland Rd<br />Cornelius, NC 28031'},
#   'lowGrade': 'K',
#   'highGrade': '5',
#   'schoolLevel': 'Elementary',
#   'isCharterSchool': 'No',
#   'isMagnetSchool': 'No',
#   'isVirtualSchool': 'No',
#   'isTitleISchool': 'No',
#   'isTitleISchoolwideSchool': 'No',
#   'district': {'districtID': '3702970',
#    'districtName': 'Charlotte-Mecklenburg Schools',
#    'url': 'https://www.schooldigger.com/go/NC/district/02970/search.aspx',
#    'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=02970'},
#   'county': {'countyName': 'Mecklenburg',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#   'rankHistory': [{'year': 2019,
#     'rank': 151,
#     'rankOf': 1461,
#     'rankStars': 4,
#     'rankLevel': 'Elementary',
#     'rankStatewidePercentage': 89.66,
#     'averageStandardScore': 86.14046},
#    {'year': 2018,
#     'rank': 89,
#     'rankOf': 1434,
#     'rankStars': 5,
#     'rankLevel': 'Elementary',
#     'rankStatewidePercentage': 93.79,
#     'averageStandardScore': 90.33965}],
#   'rankMovement': -62,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2017,
#     'numberOfStudents': 1033,
#     'percentFreeDiscLunch': 18.39,
#     'percentofAfricanAmericanStudents': 8.33,
#     'percentofAsianStudents': 3.29,
#     'percentofHispanicStudents': 10.07,
#     'percentofIndianStudents': 0.19,
#     'percentofPacificIslanderStudents': 0.29,
#     'percentofWhiteStudents': 74.35,
#     'percentofTwoOrMoreRaceStudents': 3.48,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 51.5,
#     'pupilTeacherRatio': 20.0,
#     'numberofAfricanAmericanStudents': 86,
#     'numberofAsianStudents': 34,
#     'numberofHispanicStudents': 104,
#     'numberofIndianStudents': 2,
#     'numberofPacificIslanderStudents': 3,
#     'numberofWhiteStudents': 768,
#     'numberofTwoOrMoreRaceStudents': 36,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': 2016,
#     'numberOfStudents': 985,
#     'percentFreeDiscLunch': 20.0,
#     'percentofAfricanAmericanStudents': 8.73,
#     'percentofAsianStudents': 3.25,
#     'percentofHispanicStudents': 8.12,
#     'percentofIndianStudents': 0.41,
#     'percentofPacificIslanderStudents': 0.2,
#     'percentofWhiteStudents': 76.75,
#     'percentofTwoOrMoreRaceStudents': 2.54,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 51.0,
#     'pupilTeacherRatio': 19.3,
#     'numberofAfricanAmericanStudents': 86,
#     'numberofAsianStudents': 32,
#     'numberofHispanicStudents': 80,
#     'numberofIndianStudents': 4,
#     'numberofPacificIslanderStudents': 2,
#     'numberofWhiteStudents': 756,
#     'numberofTwoOrMoreRaceStudents': 25,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': False,
#   'privateDays': None,
#   'privateHours': None,
#   'privateHasLibrary': None,
#   'privateCoed': None,
#   'privateOrientation': None,
#   'hasBoundary': True},
#  {'schoolid': '370037103335',
#   'schoolName': 'Lakeside Charter Academy',
#   'phone': '(704) 896-9500',
#   'url': 'https://www.schooldigger.com/go/NC/schools/0037103335/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0037103335/search.aspx',
#   'address': {'latLong': {'latitude': 35.45164, 'longitude': -80.843621},
#    'street': '17609 Old Statesville Rd',
#    'city': 'Cornelius',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28031',
#    'zip4': '',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Cornelius/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28031/search.aspx',
#    'html': '17609 Old Statesville Rd<br />Cornelius, NC 28031'},
#   'lowGrade': 'K',
#   'highGrade': '8',
#   'schoolLevel': 'Elementary',
#   'isCharterSchool': 'Yes',
#   'isMagnetSchool': 'No',
#   'isVirtualSchool': 'No',
#   'isTitleISchool': 'No',
#   'isTitleISchoolwideSchool': 'No',
#   'district': {'districtID': '3700371',
#    'districtName': 'Lakeside Charter Academy fka Thunderbird',
#    'url': 'https://www.schooldigger.com/go/NC/district/00371/search.aspx',
#    'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=00371'},
#   'county': {'countyName': 'Mecklenburg',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#   'rankHistory': [{'year': 2019,
#     'rank': 1131,
#     'rankOf': 1461,
#     'rankStars': 1,
#     'rankLevel': 'Elementary',
#     'rankStatewidePercentage': 22.59,
#     'averageStandardScore': 27.3605},
#    {'year': 2018,
#     'rank': 1004,
#     'rankOf': 1434,
#     'rankStars': 2,
#     'rankLevel': 'Elementary',
#     'rankStatewidePercentage': 29.99,
#     'averageStandardScore': 35.08808}],
#   'rankMovement': -127,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2017,
#     'numberOfStudents': 157,
#     'percentFreeDiscLunch': None,
#     'percentofAfricanAmericanStudents': 14.01,
#     'percentofAsianStudents': 5.1,
#     'percentofHispanicStudents': 9.55,
#     'percentofIndianStudents': 0.0,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 64.33,
#     'percentofTwoOrMoreRaceStudents': 7.01,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 19.0,
#     'pupilTeacherRatio': 8.2,
#     'numberofAfricanAmericanStudents': 22,
#     'numberofAsianStudents': 8,
#     'numberofHispanicStudents': 15,
#     'numberofIndianStudents': 0,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 101,
#     'numberofTwoOrMoreRaceStudents': 11,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': 2016,
#     'numberOfStudents': 499,
#     'percentFreeDiscLunch': 0.0,
#     'percentofAfricanAmericanStudents': 4.21,
#     'percentofAsianStudents': 2.2,
#     'percentofHispanicStudents': 8.22,
#     'percentofIndianStudents': 0.4,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 81.76,
#     'percentofTwoOrMoreRaceStudents': 3.21,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 36.0,
#     'pupilTeacherRatio': 13.8,
#     'numberofAfricanAmericanStudents': 21,
#     'numberofAsianStudents': 11,
#     'numberofHispanicStudents': 41,
#     'numberofIndianStudents': 2,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 408,
#     'numberofTwoOrMoreRaceStudents': 16,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': False,
#   'privateDays': None,
#   'privateHours': None,
#   'privateHasLibrary': None,
#   'privateCoed': None,
#   'privateOrientation': None,
#   'hasBoundary': False},
#  {'schoolid': '370297003175',
#   'schoolName': 'William Amos Hough High',
#   'phone': '(980) 344-0514',
#   'url': 'https://www.schooldigger.com/go/NC/schools/0297003175/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0297003175/search.aspx',
#   'address': {'latLong': {'latitude': 35.46729, 'longitude': -80.827491},
#    'street': '12420 Bailey Rd',
#    'city': 'Cornelius',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28031',
#    'zip4': '',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Cornelius/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28031/search.aspx',
#    'html': '12420 Bailey Rd<br />Cornelius, NC 28031'},
#   'lowGrade': '9',
#   'highGrade': '12',
#   'schoolLevel': 'High',
#   'isCharterSchool': 'No',
#   'isMagnetSchool': 'No',
#   'isVirtualSchool': 'No',
#   'isTitleISchool': 'No',
#   'isTitleISchoolwideSchool': 'No',
#   'district': {'districtID': '3702970',
#    'districtName': 'Charlotte-Mecklenburg Schools',
#    'url': 'https://www.schooldigger.com/go/NC/district/02970/search.aspx',
#    'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=02970'},
#   'county': {'countyName': 'Mecklenburg',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#   'rankHistory': [{'year': 2019,
#     'rank': 47,
#     'rankOf': 510,
#     'rankStars': 5,
#     'rankLevel': 'High',
#     'rankStatewidePercentage': 90.78,
#     'averageStandardScore': 81.32238},
#    {'year': 2018,
#     'rank': 20,
#     'rankOf': 469,
#     'rankStars': 5,
#     'rankLevel': 'High',
#     'rankStatewidePercentage': 95.74,
#     'averageStandardScore': 89.6251}],
#   'rankMovement': -27,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2017,
#     'numberOfStudents': 2594,
#     'percentFreeDiscLunch': 14.46,
#     'percentofAfricanAmericanStudents': 10.22,
#     'percentofAsianStudents': 2.54,
#     'percentofHispanicStudents': 9.02,
#     'percentofIndianStudents': 0.35,
#     'percentofPacificIslanderStudents': 0.19,
#     'percentofWhiteStudents': 75.13,
#     'percentofTwoOrMoreRaceStudents': 2.54,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 129.0,
#     'pupilTeacherRatio': 20.1,
#     'numberofAfricanAmericanStudents': 265,
#     'numberofAsianStudents': 66,
#     'numberofHispanicStudents': 234,
#     'numberofIndianStudents': 9,
#     'numberofPacificIslanderStudents': 5,
#     'numberofWhiteStudents': 1949,
#     'numberofTwoOrMoreRaceStudents': 66,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': 2016,
#     'numberOfStudents': 2572,
#     'percentFreeDiscLunch': 16.8,
#     'percentofAfricanAmericanStudents': 10.85,
#     'percentofAsianStudents': 2.57,
#     'percentofHispanicStudents': 7.47,
#     'percentofIndianStudents': 0.51,
#     'percentofPacificIslanderStudents': 0.16,
#     'percentofWhiteStudents': 76.21,
#     'percentofTwoOrMoreRaceStudents': 2.26,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 127.0,
#     'pupilTeacherRatio': 20.2,
#     'numberofAfricanAmericanStudents': 279,
#     'numberofAsianStudents': 66,
#     'numberofHispanicStudents': 192,
#     'numberofIndianStudents': 13,
#     'numberofPacificIslanderStudents': 4,
#     'numberofWhiteStudents': 1960,
#     'numberofTwoOrMoreRaceStudents': 58,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': False,
#   'privateDays': None,
#   'privateHours': None,
#   'privateHasLibrary': None,
#   'privateCoed': None,
#   'privateOrientation': None,
#   'hasBoundary': True}]

# %%
school_dict = [] 

# Loop through all the cities in our list
for school in range(len(schoolList)):
    #response = requests.get(url, verify = verify).json() # Api call
    school_lng = schoolList[school]["address"]["latLong"]["longitude"]
    school_lat = schoolList[school]["address"]["latLong"]["latitude"]
    school_names = schoolList[school]["schoolName"]
    school_street = schoolList[school]["address"]["street"]
    school_states = schoolList[school]["address"]["state"]
    school_city = schoolList[school]["address"]["city"]
    school_county = schoolList[school]["county"]["countyName"]
    school_zip = schoolList[school]["address"]["zip"]
    school_level = schoolList[school]["schoolLevel"]
    school_year = schoolList[school]["schoolYearlyDetails"][0]["year"]
    students_number = schoolList[school]["schoolYearlyDetails"][0]["numberOfStudents"]
        
    school_dict.append({
        "schoolName": school_names,
        "street": school_street,
        "zip": school_zip,
        "state": school_states,
        "city": school_city,
        "countyName": school_county,
        "schoolYear" : school_year,
        "schoolLevel": school_level,
        "longitude": school_lng,
        "latitude": school_lat,
        "studentsNumber": students_number
    })
        
Cornelius_data = pd.DataFrame(school_dict)
Cornelius_data
# Out:
#         city   countyName   latitude  longitude schoolLevel  \
# 0  Cornelius  Mecklenburg  35.467451 -80.837951      Middle
# 1  Cornelius  Mecklenburg  35.481720 -80.864216  Elementary
# 2  Cornelius  Mecklenburg  35.452743 -80.867257     Private
# 3  Cornelius  Mecklenburg  35.466507 -80.868005  Elementary
# 4  Cornelius  Mecklenburg  35.451640 -80.843621  Elementary
# 5  Cornelius  Mecklenburg  35.467290 -80.827491        High
#
#                  schoolName  schoolYear state                    street  \
# 0             Bailey Middle        2017    NC           11900 Bailey Rd
# 1      Cornelius Elementary        2017    NC         21126 Catawba Ave
# 2    Grace Covenant Academy        2018    NC      17301 Statesville Rd
# 3    J.V. Washam Elementary        2017    NC      9611 Westmoreland Rd
# 4  Lakeside Charter Academy        2017    NC  17609 Old Statesville Rd
# 5   William Amos Hough High        2017    NC           12420 Bailey Rd
#
#    studentsNumber    zip
# 0            1666  28031
# 1             605  28031
# 2             167  28031
# 3            1033  28031
# 4             157  28031
# 5            2594  28031

# %%
Cornelius_data.to_csv("Cornelius_data.csv", index=False)
