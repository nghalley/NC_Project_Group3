# %%
import pandas as pd
from pprint import pprint
import requests
import json

# %%
url='https://api.schooldigger.com/v1.2/schools?st=NC&city=Pineville&page=1&perPage=50&appID=1b789824&appKey=ae269c64511c0d65f57b507e2a200ee2'

# %%
verify = 'cacert.pem'

# %%
schools_response = requests.get(url, verify = verify)
schools_json = schools_response.json()

# %%
schools = pprint(schools_json)
# Out:
# {'numberOfPages': 1,
#  'numberOfSchools': 3,
#  'schoolList': [{'address': {'city': 'Pineville',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Pineville/search.aspx',
#                              'html': '204 Lowery St<br />Pineville, NC '
#                                      '28134-8515',
#                              'latLong': {'latitude': 35.081481,
#                                          'longitude': -80.889505},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': '204 Lowery St',
#                              'zip': '28134',
#                              'zip4': '8515',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28134/search.aspx'},
#                  'county': {'countyName': 'Mecklenburg',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#                  'district': {'districtID': '3702970',
#                               'districtName': 'Charlotte-Mecklenburg Schools',
#                               'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=02970',
#                               'url': 'https://www.schooldigger.com/go/NC/district/02970/search.aspx'},
#                  'hasBoundary': True,
#                  'highGrade': '5',
#                  'isCharterSchool': 'No',
#                  'isMagnetSchool': 'No',
#                  'isPrivate': False,
#                  'isTitleISchool': 'No',
#                  'isTitleISchoolwideSchool': 'No',
#                  'isVirtualSchool': 'No',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': 'K',
#                  'phone': '(980) 343-3920',
#                  'privateCoed': None,
#                  'privateDays': None,
#                  'privateHasLibrary': None,
#                  'privateHours': None,
#                  'privateOrientation': None,
#                  'rankHistory': [{'averageStandardScore': 58.63333,
#                                   'rank': 602,
#                                   'rankLevel': 'Elementary',
#                                   'rankOf': 1461,
#                                   'rankStars': 3,
#                                   'rankStatewidePercentage': 58.8,
#                                   'year': 2019},
#                                  {'averageStandardScore': 66.69757,
#                                   'rank': 472,
#                                   'rankLevel': 'Elementary',
#                                   'rankOf': 1434,
#                                   'rankStars': 3,
#                                   'rankStatewidePercentage': 67.09,
#                                   'year': 2018}],
#                  'rankMovement': -130,
#                  'schoolLevel': 'Elementary',
#                  'schoolName': 'Pineville Elementary',
#                  'schoolYearlyDetails': [{'numberOfStudents': 785,
#                                           'numberofAfricanAmericanStudents': 197,
#                                           'numberofAsianStudents': 26,
#                                           'numberofHispanicStudents': 288,
#                                           'numberofIndianStudents': 3,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 21,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 250,
#                                           'percentFreeDiscLunch': 64.46,
#                                           'percentofAfricanAmericanStudents': 25.1,
#                                           'percentofAsianStudents': 3.31,
#                                           'percentofHispanicStudents': 36.69,
#                                           'percentofIndianStudents': 0.38,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 2.68,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 31.85,
#                                           'pupilTeacherRatio': 16.0,
#                                           'teachersFulltime': 48.8,
#                                           'year': 2017},
#                                          {'numberOfStudents': 823,
#                                           'numberofAfricanAmericanStudents': 209,
#                                           'numberofAsianStudents': 38,
#                                           'numberofHispanicStudents': 264,
#                                           'numberofIndianStudents': 4,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 13,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 295,
#                                           'percentFreeDiscLunch': 59.66,
#                                           'percentofAfricanAmericanStudents': 25.39,
#                                           'percentofAsianStudents': 4.62,
#                                           'percentofHispanicStudents': 32.08,
#                                           'percentofIndianStudents': 0.49,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 1.58,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 35.84,
#                                           'pupilTeacherRatio': 17.5,
#                                           'teachersFulltime': 47.0,
#                                           'year': 2016}],
#                  'schoolid': '370297001260',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/0297001260/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0297001260/search.aspx'},
#                 {'address': {'city': 'Pineville',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Pineville/search.aspx',
#                              'html': '12416 Lancaster Hwy<br />Pineville, NC '
#                                      '28134',
#                              'latLong': {'latitude': 35.072763,
#                                          'longitude': -80.880152},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': '12416 Lancaster Hwy',
#                              'zip': '28134',
#                              'zip4': '',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28134/search.aspx'},
#                  'county': {'countyName': 'Mecklenburg',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#                  'hasBoundary': False,
#                  'highGrade': '12',
#                  'isCharterSchool': '(n/a)',
#                  'isMagnetSchool': '(n/a)',
#                  'isPrivate': True,
#                  'isTitleISchool': '(n/a)',
#                  'isTitleISchoolwideSchool': '(n/a)',
#                  'isVirtualSchool': '(n/a)',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': 'PK',
#                  'phone': '(704) 544-7323',
#                  'privateCoed': 'Coed',
#                  'privateDays': 180,
#                  'privateHasLibrary': True,
#                  'privateHours': 6.7,
#                  'privateOrientation': 'Baptist',
#                  'rankHistory': None,
#                  'rankMovement': None,
#                  'schoolLevel': 'Private',
#                  'schoolName': 'South Charlotte Baptist Academy',
#                  'schoolYearlyDetails': [{'numberOfStudents': 105,
#                                           'numberofAfricanAmericanStudents': 14,
#                                           'numberofAsianStudents': 0,
#                                           'numberofHispanicStudents': 16,
#                                           'numberofIndianStudents': 0,
#                                           'numberofPacificIslanderStudents': 1,
#                                           'numberofTwoOrMoreRaceStudents': 8,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 24,
#                                           'percentFreeDiscLunch': None,
#                                           'percentofAfricanAmericanStudents': 13.33,
#                                           'percentofAsianStudents': 0.0,
#                                           'percentofHispanicStudents': 15.24,
#                                           'percentofIndianStudents': 0.0,
#                                           'percentofPacificIslanderStudents': 0.95,
#                                           'percentofTwoOrMoreRaceStudents': 7.62,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 22.86,
#                                           'pupilTeacherRatio': 5.2,
#                                           'teachersFulltime': 12.0,
#                                           'year': 2018},
#                                          {'numberOfStudents': 105,
#                                           'numberofAfricanAmericanStudents': 14,
#                                           'numberofAsianStudents': 0,
#                                           'numberofHispanicStudents': 16,
#                                           'numberofIndianStudents': 0,
#                                           'numberofPacificIslanderStudents': 1,
#                                           'numberofTwoOrMoreRaceStudents': 8,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 24,
#                                           'percentFreeDiscLunch': None,
#                                           'percentofAfricanAmericanStudents': 13.33,
#                                           'percentofAsianStudents': 0.0,
#                                           'percentofHispanicStudents': 15.24,
#                                           'percentofIndianStudents': 0.0,
#                                           'percentofPacificIslanderStudents': 0.95,
#                                           'percentofTwoOrMoreRaceStudents': 7.62,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 22.86,
#                                           'pupilTeacherRatio': 5.2,
#                                           'teachersFulltime': 12.0,
#                                           'year': 2016}],
#                  'schoolid': '379999936632',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/9999936632/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/9999936632/search.aspx'},
#                 {'address': {'city': 'Pineville',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Pineville/search.aspx',
#                              'html': '9601 China Grove Church Rd<br '
#                                      '/>Pineville, NC 28134',
#                              'latLong': {'latitude': 35.107305,
#                                          'longitude': -80.884933},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': '9601 China Grove Church Rd',
#                              'zip': '28134',
#                              'zip4': '',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28134/search.aspx'},
#                  'county': {'countyName': 'Mecklenburg',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#                  'district': {'districtID': '3702970',
#                               'districtName': 'Charlotte-Mecklenburg Schools',
#                               'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=02970',
#                               'url': 'https://www.schooldigger.com/go/NC/district/02970/search.aspx'},
#                  'hasBoundary': True,
#                  'highGrade': '5',
#                  'isCharterSchool': 'No',
#                  'isMagnetSchool': 'No',
#                  'isPrivate': False,
#                  'isTitleISchool': 'Yes',
#                  'isTitleISchoolwideSchool': 'No',
#                  'isVirtualSchool': 'No',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': 'PK',
#                  'phone': '(980) 343-3636',
#                  'privateCoed': None,
#                  'privateDays': None,
#                  'privateHasLibrary': None,
#                  'privateHours': None,
#                  'privateOrientation': None,
#                  'rankHistory': [{'averageStandardScore': 9.85538,
#                                   'rank': 1374,
#                                   'rankLevel': 'Elementary',
#                                   'rankOf': 1461,
#                                   'rankStars': 0,
#                                   'rankStatewidePercentage': 5.95,
#                                   'year': 2019},
#                                  {'averageStandardScore': 12.20652,
#                                   'rank': 1310,
#                                   'rankLevel': 'Elementary',
#                                   'rankOf': 1434,
#                                   'rankStars': 0,
#                                   'rankStatewidePercentage': 8.65,
#                                   'year': 2018}],
#                  'rankMovement': -64,
#                  'schoolLevel': 'Elementary',
#                  'schoolName': 'Sterling Elementary',
#                  'schoolYearlyDetails': [{'numberOfStudents': 648,
#                                           'numberofAfricanAmericanStudents': 238,
#                                           'numberofAsianStudents': 7,
#                                           'numberofHispanicStudents': 376,
#                                           'numberofIndianStudents': 3,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 10,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 14,
#                                           'percentFreeDiscLunch': 99.54,
#                                           'percentofAfricanAmericanStudents': 36.73,
#                                           'percentofAsianStudents': 1.08,
#                                           'percentofHispanicStudents': 58.02,
#                                           'percentofIndianStudents': 0.46,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 1.54,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 2.16,
#                                           'pupilTeacherRatio': 16.8,
#                                           'teachersFulltime': 38.4,
#                                           'year': 2017},
#                                          {'numberOfStudents': 639,
#                                           'numberofAfricanAmericanStudents': 256,
#                                           'numberofAsianStudents': 7,
#                                           'numberofHispanicStudents': 351,
#                                           'numberofIndianStudents': 0,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 6,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 19,
#                                           'percentFreeDiscLunch': 98.75,
#                                           'percentofAfricanAmericanStudents': 40.06,
#                                           'percentofAsianStudents': 1.1,
#                                           'percentofHispanicStudents': 54.93,
#                                           'percentofIndianStudents': 0.0,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 0.94,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 2.97,
#                                           'pupilTeacherRatio': 14.8,
#                                           'teachersFulltime': 43.0,
#                                           'year': 2016}],
#                  'schoolid': '370297001279',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/0297001279/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0297001279/search.aspx'}]}

# %%
schoolList = schools_json["schoolList"]
schoolList
# Out:
# [{'schoolid': '370297001260',
#   'schoolName': 'Pineville Elementary',
#   'phone': '(980) 343-3920',
#   'url': 'https://www.schooldigger.com/go/NC/schools/0297001260/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0297001260/search.aspx',
#   'address': {'latLong': {'latitude': 35.081481, 'longitude': -80.889505},
#    'street': '204 Lowery St',
#    'city': 'Pineville',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28134',
#    'zip4': '8515',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Pineville/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28134/search.aspx',
#    'html': '204 Lowery St<br />Pineville, NC 28134-8515'},
#   'lowGrade': 'K',
#   'highGrade': '5',
#   'schoolLevel': 'Elementary',
#   'isCharterSchool': 'No',
#   'isMagnetSchool': 'No',
#   'isVirtualSchool': 'No',
#   'isTitleISchool': 'No',
#   'isTitleISchoolwideSchool': 'No',
#   'district': {'districtID': '3702970',
#    'districtName': 'Charlotte-Mecklenburg Schools',
#    'url': 'https://www.schooldigger.com/go/NC/district/02970/search.aspx',
#    'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=02970'},
#   'county': {'countyName': 'Mecklenburg',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#   'rankHistory': [{'year': 2019,
#     'rank': 602,
#     'rankOf': 1461,
#     'rankStars': 3,
#     'rankLevel': 'Elementary',
#     'rankStatewidePercentage': 58.8,
#     'averageStandardScore': 58.63333},
#    {'year': 2018,
#     'rank': 472,
#     'rankOf': 1434,
#     'rankStars': 3,
#     'rankLevel': 'Elementary',
#     'rankStatewidePercentage': 67.09,
#     'averageStandardScore': 66.69757}],
#   'rankMovement': -130,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2017,
#     'numberOfStudents': 785,
#     'percentFreeDiscLunch': 64.46,
#     'percentofAfricanAmericanStudents': 25.1,
#     'percentofAsianStudents': 3.31,
#     'percentofHispanicStudents': 36.69,
#     'percentofIndianStudents': 0.38,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 31.85,
#     'percentofTwoOrMoreRaceStudents': 2.68,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 48.8,
#     'pupilTeacherRatio': 16.0,
#     'numberofAfricanAmericanStudents': 197,
#     'numberofAsianStudents': 26,
#     'numberofHispanicStudents': 288,
#     'numberofIndianStudents': 3,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 250,
#     'numberofTwoOrMoreRaceStudents': 21,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': 2016,
#     'numberOfStudents': 823,
#     'percentFreeDiscLunch': 59.66,
#     'percentofAfricanAmericanStudents': 25.39,
#     'percentofAsianStudents': 4.62,
#     'percentofHispanicStudents': 32.08,
#     'percentofIndianStudents': 0.49,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 35.84,
#     'percentofTwoOrMoreRaceStudents': 1.58,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 47.0,
#     'pupilTeacherRatio': 17.5,
#     'numberofAfricanAmericanStudents': 209,
#     'numberofAsianStudents': 38,
#     'numberofHispanicStudents': 264,
#     'numberofIndianStudents': 4,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 295,
#     'numberofTwoOrMoreRaceStudents': 13,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': False,
#   'privateDays': None,
#   'privateHours': None,
#   'privateHasLibrary': None,
#   'privateCoed': None,
#   'privateOrientation': None,
#   'hasBoundary': True},
#  {'schoolid': '379999936632',
#   'schoolName': 'South Charlotte Baptist Academy',
#   'phone': '(704) 544-7323',
#   'url': 'https://www.schooldigger.com/go/NC/schools/9999936632/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/9999936632/search.aspx',
#   'address': {'latLong': {'latitude': 35.072763, 'longitude': -80.880152},
#    'street': '12416 Lancaster Hwy',
#    'city': 'Pineville',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28134',
#    'zip4': '',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Pineville/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28134/search.aspx',
#    'html': '12416 Lancaster Hwy<br />Pineville, NC 28134'},
#   'lowGrade': 'PK',
#   'highGrade': '12',
#   'schoolLevel': 'Private',
#   'isCharterSchool': '(n/a)',
#   'isMagnetSchool': '(n/a)',
#   'isVirtualSchool': '(n/a)',
#   'isTitleISchool': '(n/a)',
#   'isTitleISchoolwideSchool': '(n/a)',
#   'county': {'countyName': 'Mecklenburg',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#   'rankHistory': None,
#   'rankMovement': None,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2018,
#     'numberOfStudents': 105,
#     'percentFreeDiscLunch': None,
#     'percentofAfricanAmericanStudents': 13.33,
#     'percentofAsianStudents': 0.0,
#     'percentofHispanicStudents': 15.24,
#     'percentofIndianStudents': 0.0,
#     'percentofPacificIslanderStudents': 0.95,
#     'percentofWhiteStudents': 22.86,
#     'percentofTwoOrMoreRaceStudents': 7.62,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 12.0,
#     'pupilTeacherRatio': 5.2,
#     'numberofAfricanAmericanStudents': 14,
#     'numberofAsianStudents': 0,
#     'numberofHispanicStudents': 16,
#     'numberofIndianStudents': 0,
#     'numberofPacificIslanderStudents': 1,
#     'numberofWhiteStudents': 24,
#     'numberofTwoOrMoreRaceStudents': 8,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': 2016,
#     'numberOfStudents': 105,
#     'percentFreeDiscLunch': None,
#     'percentofAfricanAmericanStudents': 13.33,
#     'percentofAsianStudents': 0.0,
#     'percentofHispanicStudents': 15.24,
#     'percentofIndianStudents': 0.0,
#     'percentofPacificIslanderStudents': 0.95,
#     'percentofWhiteStudents': 22.86,
#     'percentofTwoOrMoreRaceStudents': 7.62,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 12.0,
#     'pupilTeacherRatio': 5.2,
#     'numberofAfricanAmericanStudents': 14,
#     'numberofAsianStudents': 0,
#     'numberofHispanicStudents': 16,
#     'numberofIndianStudents': 0,
#     'numberofPacificIslanderStudents': 1,
#     'numberofWhiteStudents': 24,
#     'numberofTwoOrMoreRaceStudents': 8,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': True,
#   'privateDays': 180,
#   'privateHours': 6.7,
#   'privateHasLibrary': True,
#   'privateCoed': 'Coed',
#   'privateOrientation': 'Baptist',
#   'hasBoundary': False},
#  {'schoolid': '370297001279',
#   'schoolName': 'Sterling Elementary',
#   'phone': '(980) 343-3636',
#   'url': 'https://www.schooldigger.com/go/NC/schools/0297001279/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0297001279/search.aspx',
#   'address': {'latLong': {'latitude': 35.107305, 'longitude': -80.884933},
#    'street': '9601 China Grove Church Rd',
#    'city': 'Pineville',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28134',
#    'zip4': '',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Pineville/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28134/search.aspx',
#    'html': '9601 China Grove Church Rd<br />Pineville, NC 28134'},
#   'lowGrade': 'PK',
#   'highGrade': '5',
#   'schoolLevel': 'Elementary',
#   'isCharterSchool': 'No',
#   'isMagnetSchool': 'No',
#   'isVirtualSchool': 'No',
#   'isTitleISchool': 'Yes',
#   'isTitleISchoolwideSchool': 'No',
#   'district': {'districtID': '3702970',
#    'districtName': 'Charlotte-Mecklenburg Schools',
#    'url': 'https://www.schooldigger.com/go/NC/district/02970/search.aspx',
#    'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=02970'},
#   'county': {'countyName': 'Mecklenburg',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#   'rankHistory': [{'year': 2019,
#     'rank': 1374,
#     'rankOf': 1461,
#     'rankStars': 0,
#     'rankLevel': 'Elementary',
#     'rankStatewidePercentage': 5.95,
#     'averageStandardScore': 9.85538},
#    {'year': 2018,
#     'rank': 1310,
#     'rankOf': 1434,
#     'rankStars': 0,
#     'rankLevel': 'Elementary',
#     'rankStatewidePercentage': 8.65,
#     'averageStandardScore': 12.20652}],
#   'rankMovement': -64,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2017,
#     'numberOfStudents': 648,
#     'percentFreeDiscLunch': 99.54,
#     'percentofAfricanAmericanStudents': 36.73,
#     'percentofAsianStudents': 1.08,
#     'percentofHispanicStudents': 58.02,
#     'percentofIndianStudents': 0.46,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 2.16,
#     'percentofTwoOrMoreRaceStudents': 1.54,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 38.4,
#     'pupilTeacherRatio': 16.8,
#     'numberofAfricanAmericanStudents': 238,
#     'numberofAsianStudents': 7,
#     'numberofHispanicStudents': 376,
#     'numberofIndianStudents': 3,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 14,
#     'numberofTwoOrMoreRaceStudents': 10,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': 2016,
#     'numberOfStudents': 639,
#     'percentFreeDiscLunch': 98.75,
#     'percentofAfricanAmericanStudents': 40.06,
#     'percentofAsianStudents': 1.1,
#     'percentofHispanicStudents': 54.93,
#     'percentofIndianStudents': 0.0,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 2.97,
#     'percentofTwoOrMoreRaceStudents': 0.94,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 43.0,
#     'pupilTeacherRatio': 14.8,
#     'numberofAfricanAmericanStudents': 256,
#     'numberofAsianStudents': 7,
#     'numberofHispanicStudents': 351,
#     'numberofIndianStudents': 0,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 19,
#     'numberofTwoOrMoreRaceStudents': 6,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': False,
#   'privateDays': None,
#   'privateHours': None,
#   'privateHasLibrary': None,
#   'privateCoed': None,
#   'privateOrientation': None,
#   'hasBoundary': True}]

# %%
school_dict = [] 

# Loop through all the cities in our list
for school in range(len(schoolList)):
    #response = requests.get(url, verify = verify).json() # Api call
    school_lng = schoolList[school]["address"]["latLong"]["longitude"]
    school_lat = schoolList[school]["address"]["latLong"]["latitude"]
    school_names = schoolList[school]["schoolName"]
    school_street = schoolList[school]["address"]["street"]
    school_states = schoolList[school]["address"]["state"]
    school_city = schoolList[school]["address"]["city"]
    school_county = schoolList[school]["county"]["countyName"]
    school_zip = schoolList[school]["address"]["zip"]
    school_level = schoolList[school]["schoolLevel"]
    school_year = schoolList[school]["schoolYearlyDetails"][0]["year"]
    students_number = schoolList[school]["schoolYearlyDetails"][0]["numberOfStudents"]
        
    school_dict.append({
        "schoolName": school_names,
        "street": school_street,
        "zip": school_zip,
        "state": school_states,
        "city": school_city,
        "countyName": school_county,
        "schoolYear" : school_year,
        "schoolLevel": school_level,
        "longitude": school_lng,
        "latitude": school_lat,
        "studentsNumber": students_number
    })
        
Pineville_data = pd.DataFrame(school_dict)
Pineville_data
# Out:
#         city   countyName   latitude  longitude schoolLevel  \
# 0  Pineville  Mecklenburg  35.081481 -80.889505  Elementary
# 1  Pineville  Mecklenburg  35.072763 -80.880152     Private
# 2  Pineville  Mecklenburg  35.107305 -80.884933  Elementary
#
#                         schoolName  schoolYear state  \
# 0             Pineville Elementary        2017    NC
# 1  South Charlotte Baptist Academy        2018    NC
# 2              Sterling Elementary        2017    NC
#
#                        street  studentsNumber    zip
# 0               204 Lowery St             785  28134
# 1         12416 Lancaster Hwy             105  28134
# 2  9601 China Grove Church Rd             648  28134

# %%
Pineville_data.to_csv("Pineville_data.csv", index=False)
