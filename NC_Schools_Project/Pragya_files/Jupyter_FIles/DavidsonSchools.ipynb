# %%
import pandas as pd
from pprint import pprint
import requests
import json

# %%
url='https://api.schooldigger.com/v1.2/schools?st=NC&city=Davidson&page=1&perPage=50&appID=1b789824&appKey=ae269c64511c0d65f57b507e2a200ee2'

# %%
verify = 'cacert.pem'

# %%
schools_response = requests.get(url, verify = verify)
schools_json = schools_response.json()

# %%
schools = pprint(schools_json)
# Out:
# {'numberOfPages': 1,
#  'numberOfSchools': 6,
#  'schoolList': [{'address': {'city': 'Davidson',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Davidson/search.aspx',
#                              'html': '404 Armour Street<br />Davidson, NC '
#                                      '28036',
#                              'latLong': {'latitude': 35.501804,
#                                          'longitude': -80.859593},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': '404 Armour Street',
#                              'zip': '28036',
#                              'zip4': '',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28036/search.aspx'},
#                  'county': {'countyName': 'Mecklenburg',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#                  'district': {'districtID': '3700135',
#                               'districtName': 'Community School of Davidson',
#                               'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=00135',
#                               'url': 'https://www.schooldigger.com/go/NC/district/00135/search.aspx'},
#                  'hasBoundary': False,
#                  'highGrade': '12',
#                  'isCharterSchool': 'Yes',
#                  'isMagnetSchool': 'No',
#                  'isPrivate': False,
#                  'isTitleISchool': 'No',
#                  'isTitleISchoolwideSchool': 'No',
#                  'isVirtualSchool': 'No',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': 'K',
#                  'phone': '(704) 897-8061',
#                  'privateCoed': None,
#                  'privateDays': None,
#                  'privateHasLibrary': None,
#                  'privateHours': None,
#                  'privateOrientation': None,
#                  'rankHistory': None,
#                  'rankMovement': None,
#                  'schoolLevel': 'Other',
#                  'schoolName': 'Community School of Davidson',
#                  'schoolYearlyDetails': [{'numberOfStudents': 1371,
#                                           'numberofAfricanAmericanStudents': 58,
#                                           'numberofAsianStudents': 27,
#                                           'numberofHispanicStudents': 56,
#                                           'numberofIndianStudents': 3,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 47,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 1180,
#                                           'percentFreeDiscLunch': None,
#                                           'percentofAfricanAmericanStudents': 4.23,
#                                           'percentofAsianStudents': 1.97,
#                                           'percentofHispanicStudents': 4.08,
#                                           'percentofIndianStudents': 0.22,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 3.43,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 86.07,
#                                           'pupilTeacherRatio': 14.8,
#                                           'teachersFulltime': 92.4,
#                                           'year': 2017},
#                                          {'numberOfStudents': 1342,
#                                           'numberofAfricanAmericanStudents': 56,
#                                           'numberofAsianStudents': 22,
#                                           'numberofHispanicStudents': 51,
#                                           'numberofIndianStudents': 3,
#                                           'numberofPacificIslanderStudents': 1,
#                                           'numberofTwoOrMoreRaceStudents': 45,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 1164,
#                                           'percentFreeDiscLunch': 0.0,
#                                           'percentofAfricanAmericanStudents': 4.17,
#                                           'percentofAsianStudents': 1.64,
#                                           'percentofHispanicStudents': 3.8,
#                                           'percentofIndianStudents': 0.22,
#                                           'percentofPacificIslanderStudents': 0.07,
#                                           'percentofTwoOrMoreRaceStudents': 3.35,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 86.74,
#                                           'pupilTeacherRatio': 16.3,
#                                           'teachersFulltime': 82.0,
#                                           'year': 2016}],
#                  'schoolid': '370013502736',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/0013502736/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0013502736/search.aspx'},
#                 {'address': {'city': 'Davidson',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Davidson/search.aspx',
#                              'html': '750 Jetton St<br />Davidson, NC 28036',
#                              'latLong': {'latitude': 35.503543,
#                                          'longitude': -80.860489},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': '750 Jetton St',
#                              'zip': '28036',
#                              'zip4': '',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28036/search.aspx'},
#                  'county': {'countyName': 'Mecklenburg',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#                  'hasBoundary': False,
#                  'highGrade': '12',
#                  'isCharterSchool': '(n/a)',
#                  'isMagnetSchool': '(n/a)',
#                  'isPrivate': True,
#                  'isTitleISchool': '(n/a)',
#                  'isTitleISchoolwideSchool': '(n/a)',
#                  'isVirtualSchool': '(n/a)',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': 'PK',
#                  'phone': '(704) 237-5220',
#                  'privateCoed': 'Coed',
#                  'privateDays': 173,
#                  'privateHasLibrary': True,
#                  'privateHours': 7.4,
#                  'privateOrientation': 'Nonsectarian',
#                  'rankHistory': None,
#                  'rankMovement': None,
#                  'schoolLevel': 'Private',
#                  'schoolName': 'Davidson Day School',
#                  'schoolYearlyDetails': [{'numberOfStudents': 516,
#                                           'numberofAfricanAmericanStudents': 19,
#                                           'numberofAsianStudents': 10,
#                                           'numberofHispanicStudents': 9,
#                                           'numberofIndianStudents': 2,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 6,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 427,
#                                           'percentFreeDiscLunch': None,
#                                           'percentofAfricanAmericanStudents': 3.68,
#                                           'percentofAsianStudents': 1.94,
#                                           'percentofHispanicStudents': 1.74,
#                                           'percentofIndianStudents': 0.39,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 1.16,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 82.75,
#                                           'pupilTeacherRatio': 7.2,
#                                           'teachersFulltime': 65.4,
#                                           'year': 2018},
#                                          {'numberOfStudents': 531,
#                                           'numberofAfricanAmericanStudents': 38,
#                                           'numberofAsianStudents': 12,
#                                           'numberofHispanicStudents': 10,
#                                           'numberofIndianStudents': 4,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 1,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 419,
#                                           'percentFreeDiscLunch': None,
#                                           'percentofAfricanAmericanStudents': 7.16,
#                                           'percentofAsianStudents': 2.26,
#                                           'percentofHispanicStudents': 1.88,
#                                           'percentofIndianStudents': 0.75,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 0.19,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 78.91,
#                                           'pupilTeacherRatio': 9.3,
#                                           'teachersFulltime': 51.6,
#                                           'year': 2016}],
#                  'schoolid': '379999924942',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/9999924942/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/9999924942/search.aspx'},
#                 {'address': {'city': 'Davidson',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Davidson/search.aspx',
#                              'html': '635 South St<br />Davidson, NC 28036',
#                              'latLong': {'latitude': 35.489791,
#                                          'longitude': -80.8484},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': '635 South St',
#                              'zip': '28036',
#                              'zip4': '',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28036/search.aspx'},
#                  'county': {'countyName': 'Mecklenburg',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#                  'district': {'districtID': '3702970',
#                               'districtName': 'Charlotte-Mecklenburg Schools',
#                               'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=02970',
#                               'url': 'https://www.schooldigger.com/go/NC/district/02970/search.aspx'},
#                  'hasBoundary': True,
#                  'highGrade': '5',
#                  'isCharterSchool': 'No',
#                  'isMagnetSchool': 'No',
#                  'isPrivate': False,
#                  'isTitleISchool': 'No',
#                  'isTitleISchoolwideSchool': 'No',
#                  'isVirtualSchool': 'No',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': 'K',
#                  'phone': '(980) 343-3900',
#                  'privateCoed': None,
#                  'privateDays': None,
#                  'privateHasLibrary': None,
#                  'privateHours': None,
#                  'privateOrientation': None,
#                  'rankHistory': [{'averageStandardScore': 91.07875,
#                                   'rank': 82,
#                                   'rankLevel': 'Elementary',
#                                   'rankOf': 1461,
#                                   'rankStars': 5,
#                                   'rankStatewidePercentage': 94.39,
#                                   'year': 2019},
#                                  {'averageStandardScore': 86.85336,
#                                   'rank': 138,
#                                   'rankLevel': 'Elementary',
#                                   'rankOf': 1434,
#                                   'rankStars': 5,
#                                   'rankStatewidePercentage': 90.38,
#                                   'year': 2018}],
#                  'rankMovement': 56,
#                  'schoolLevel': 'Elementary',
#                  'schoolName': 'Davidson Elementary',
#                  'schoolYearlyDetails': [{'numberOfStudents': 708,
#                                           'numberofAfricanAmericanStudents': 42,
#                                           'numberofAsianStudents': 16,
#                                           'numberofHispanicStudents': 80,
#                                           'numberofIndianStudents': 2,
#                                           'numberofPacificIslanderStudents': 3,
#                                           'numberofTwoOrMoreRaceStudents': 8,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 557,
#                                           'percentFreeDiscLunch': 15.82,
#                                           'percentofAfricanAmericanStudents': 5.93,
#                                           'percentofAsianStudents': 2.26,
#                                           'percentofHispanicStudents': 11.3,
#                                           'percentofIndianStudents': 0.28,
#                                           'percentofPacificIslanderStudents': 0.42,
#                                           'percentofTwoOrMoreRaceStudents': 1.13,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 78.67,
#                                           'pupilTeacherRatio': 17.7,
#                                           'teachersFulltime': 39.9,
#                                           'year': 2017},
#                                          {'numberOfStudents': 708,
#                                           'numberofAfricanAmericanStudents': 41,
#                                           'numberofAsianStudents': 16,
#                                           'numberofHispanicStudents': 83,
#                                           'numberofIndianStudents': 1,
#                                           'numberofPacificIslanderStudents': 2,
#                                           'numberofTwoOrMoreRaceStudents': 6,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 559,
#                                           'percentFreeDiscLunch': 14.83,
#                                           'percentofAfricanAmericanStudents': 5.79,
#                                           'percentofAsianStudents': 2.26,
#                                           'percentofHispanicStudents': 11.72,
#                                           'percentofIndianStudents': 0.14,
#                                           'percentofPacificIslanderStudents': 0.28,
#                                           'percentofTwoOrMoreRaceStudents': 0.85,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 78.95,
#                                           'pupilTeacherRatio': 19.6,
#                                           'teachersFulltime': 36.0,
#                                           'year': 2016}],
#                  'schoolid': '370297001208',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/0297001208/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0297001208/search.aspx'},
#                 {'address': {'city': 'Davidson',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Davidson/search.aspx',
#                              'html': '511 S Main St<br />Davidson, NC 28036',
#                              'latLong': {'latitude': 35.492887,
#                                          'longitude': -80.854384},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': '511 S Main St',
#                              'zip': '28036',
#                              'zip4': '',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28036/search.aspx'},
#                  'county': {'countyName': 'Mecklenburg',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#                  'hasBoundary': None,
#                  'highGrade': '7',
#                  'isCharterSchool': '(n/a)',
#                  'isMagnetSchool': '(n/a)',
#                  'isPrivate': True,
#                  'isTitleISchool': '(n/a)',
#                  'isTitleISchoolwideSchool': '(n/a)',
#                  'isVirtualSchool': '(n/a)',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': 'K',
#                  'phone': '(704) 892-0091',
#                  'privateCoed': 'Coed',
#                  'privateDays': 180,
#                  'privateHasLibrary': True,
#                  'privateHours': 7.0,
#                  'privateOrientation': 'Nonsectarian',
#                  'rankHistory': None,
#                  'rankMovement': None,
#                  'schoolLevel': 'Private',
#                  'schoolName': 'Davidson Green School',
#                  'schoolYearlyDetails': [{'numberOfStudents': 39,
#                                           'numberofAfricanAmericanStudents': 0,
#                                           'numberofAsianStudents': 0,
#                                           'numberofHispanicStudents': 0,
#                                           'numberofIndianStudents': 0,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 0,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 0,
#                                           'percentFreeDiscLunch': None,
#                                           'percentofAfricanAmericanStudents': 0.0,
#                                           'percentofAsianStudents': 0.0,
#                                           'percentofHispanicStudents': 0.0,
#                                           'percentofIndianStudents': 0.0,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 0.0,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 0.0,
#                                           'pupilTeacherRatio': 6.3,
#                                           'teachersFulltime': 6.1,
#                                           'year': 2018},
#                                          {'numberOfStudents': None,
#                                           'numberofAfricanAmericanStudents': None,
#                                           'numberofAsianStudents': None,
#                                           'numberofHispanicStudents': None,
#                                           'numberofIndianStudents': None,
#                                           'numberofPacificIslanderStudents': None,
#                                           'numberofTwoOrMoreRaceStudents': None,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': None,
#                                           'percentFreeDiscLunch': None,
#                                           'percentofAfricanAmericanStudents': None,
#                                           'percentofAsianStudents': None,
#                                           'percentofHispanicStudents': None,
#                                           'percentofIndianStudents': None,
#                                           'percentofPacificIslanderStudents': None,
#                                           'percentofTwoOrMoreRaceStudents': None,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': None,
#                                           'pupilTeacherRatio': None,
#                                           'teachersFulltime': None,
#                                           'year': None}],
#                  'schoolid': '379999950673',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/9999950673/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/9999950673/search.aspx'},
#                 {'address': {'city': 'Davidson',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Davidson/search.aspx',
#                              'html': '251 S St<br />Davidson, NC 28036',
#                              'latLong': {'latitude': 35.496126,
#                                          'longitude': -80.848806},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': '251 S St',
#                              'zip': '28036',
#                              'zip4': '',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28036/search.aspx'},
#                  'county': {'countyName': 'Mecklenburg',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#                  'hasBoundary': False,
#                  'highGrade': '12',
#                  'isCharterSchool': '(n/a)',
#                  'isMagnetSchool': '(n/a)',
#                  'isPrivate': True,
#                  'isTitleISchool': '(n/a)',
#                  'isTitleISchoolwideSchool': '(n/a)',
#                  'isVirtualSchool': '(n/a)',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': 'K',
#                  'phone': '(704) 987-9811',
#                  'privateCoed': 'Coed',
#                  'privateDays': 178,
#                  'privateHasLibrary': True,
#                  'privateHours': 7.0,
#                  'privateOrientation': 'Christian (no specific denomination)',
#                  'rankHistory': None,
#                  'rankMovement': None,
#                  'schoolLevel': 'Private',
#                  'schoolName': 'Lake Norman Christian School',
#                  'schoolYearlyDetails': [{'numberOfStudents': 141,
#                                           'numberofAfricanAmericanStudents': 5,
#                                           'numberofAsianStudents': 2,
#                                           'numberofHispanicStudents': 18,
#                                           'numberofIndianStudents': 3,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 3,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 110,
#                                           'percentFreeDiscLunch': None,
#                                           'percentofAfricanAmericanStudents': 3.55,
#                                           'percentofAsianStudents': 1.42,
#                                           'percentofHispanicStudents': 12.77,
#                                           'percentofIndianStudents': 2.13,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 2.13,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 78.01,
#                                           'pupilTeacherRatio': 7.4,
#                                           'teachersFulltime': 18.9,
#                                           'year': 2018},
#                                          {'numberOfStudents': 138,
#                                           'numberofAfricanAmericanStudents': 4,
#                                           'numberofAsianStudents': 6,
#                                           'numberofHispanicStudents': 18,
#                                           'numberofIndianStudents': 0,
#                                           'numberofPacificIslanderStudents': 1,
#                                           'numberofTwoOrMoreRaceStudents': 3,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 106,
#                                           'percentFreeDiscLunch': None,
#                                           'percentofAfricanAmericanStudents': 2.9,
#                                           'percentofAsianStudents': 4.35,
#                                           'percentofHispanicStudents': 13.04,
#                                           'percentofIndianStudents': 0.0,
#                                           'percentofPacificIslanderStudents': 0.72,
#                                           'percentofTwoOrMoreRaceStudents': 2.17,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 76.81,
#                                           'pupilTeacherRatio': 7.8,
#                                           'teachersFulltime': 17.6,
#                                           'year': 2016}],
#                  'schoolid': '379999937359',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/9999937359/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/9999937359/search.aspx'},
#                 {'address': {'city': 'Davidson',
#                              'cityURL': 'https://www.schooldigger.com/go/NC/city/Davidson/search.aspx',
#                              'html': 'PO Box 549<br />Davidson, NC 28036',
#                              'latLong': {'latitude': None, 'longitude': None},
#                              'state': 'NC',
#                              'stateFull': 'North Carolina',
#                              'street': 'PO Box 549',
#                              'zip': '28036',
#                              'zip4': '',
#                              'zipURL': 'https://www.schooldigger.com/go/NC/zip/28036/search.aspx'},
#                  'county': {'countyName': 'Iredell',
#                             'countyURL': 'https://www.schooldigger.com/go/NC/county/Iredell/search.aspx'},
#                  'hasBoundary': False,
#                  'highGrade': '12',
#                  'isCharterSchool': '(n/a)',
#                  'isMagnetSchool': '(n/a)',
#                  'isPrivate': True,
#                  'isTitleISchool': '(n/a)',
#                  'isTitleISchoolwideSchool': '(n/a)',
#                  'isVirtualSchool': '(n/a)',
#                  'locationIsWithinBoundary': None,
#                  'lowGrade': 'K',
#                  'phone': '(704) 895-8653',
#                  'privateCoed': 'Coed',
#                  'privateDays': 177,
#                  'privateHasLibrary': False,
#                  'privateHours': 7.0,
#                  'privateOrientation': 'Nonsectarian',
#                  'rankHistory': None,
#                  'rankMovement': None,
#                  'schoolLevel': 'Private',
#                  'schoolName': 'Woodlawn School',
#                  'schoolYearlyDetails': [{'numberOfStudents': 212,
#                                           'numberofAfricanAmericanStudents': 11,
#                                           'numberofAsianStudents': 7,
#                                           'numberofHispanicStudents': 10,
#                                           'numberofIndianStudents': 0,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 0,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 184,
#                                           'percentFreeDiscLunch': None,
#                                           'percentofAfricanAmericanStudents': 5.19,
#                                           'percentofAsianStudents': 3.3,
#                                           'percentofHispanicStudents': 4.72,
#                                           'percentofIndianStudents': 0.0,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 0.0,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 86.79,
#                                           'pupilTeacherRatio': 7.5,
#                                           'teachersFulltime': 27.9,
#                                           'year': 2018},
#                                          {'numberOfStudents': 197,
#                                           'numberofAfricanAmericanStudents': 3,
#                                           'numberofAsianStudents': 4,
#                                           'numberofHispanicStudents': 7,
#                                           'numberofIndianStudents': 0,
#                                           'numberofPacificIslanderStudents': 0,
#                                           'numberofTwoOrMoreRaceStudents': 4,
#                                           'numberofUnspecifiedRaceStudents': None,
#                                           'numberofWhiteStudents': 179,
#                                           'percentFreeDiscLunch': None,
#                                           'percentofAfricanAmericanStudents': 1.52,
#                                           'percentofAsianStudents': 2.03,
#                                           'percentofHispanicStudents': 3.55,
#                                           'percentofIndianStudents': 0.0,
#                                           'percentofPacificIslanderStudents': 0.0,
#                                           'percentofTwoOrMoreRaceStudents': 2.03,
#                                           'percentofUnspecifiedRaceStudents': None,
#                                           'percentofWhiteStudents': 90.86,
#                                           'pupilTeacherRatio': 7.2,
#                                           'teachersFulltime': 27.1,
#                                           'year': 2016}],
#                  'schoolid': '379999933916',
#                  'url': 'https://www.schooldigger.com/go/NC/schools/9999933916/school.aspx',
#                  'urlCompare': 'https://www.schooldigger.com/go/NC/schools/9999933916/search.aspx'}]}

# %%
schoolList = schools_json["schoolList"]
schoolList
# Out:
# [{'schoolid': '370013502736',
#   'schoolName': 'Community School of Davidson',
#   'phone': '(704) 897-8061',
#   'url': 'https://www.schooldigger.com/go/NC/schools/0013502736/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0013502736/search.aspx',
#   'address': {'latLong': {'latitude': 35.501804, 'longitude': -80.859593},
#    'street': '404 Armour Street',
#    'city': 'Davidson',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28036',
#    'zip4': '',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Davidson/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28036/search.aspx',
#    'html': '404 Armour Street<br />Davidson, NC 28036'},
#   'lowGrade': 'K',
#   'highGrade': '12',
#   'schoolLevel': 'Other',
#   'isCharterSchool': 'Yes',
#   'isMagnetSchool': 'No',
#   'isVirtualSchool': 'No',
#   'isTitleISchool': 'No',
#   'isTitleISchoolwideSchool': 'No',
#   'district': {'districtID': '3700135',
#    'districtName': 'Community School of Davidson',
#    'url': 'https://www.schooldigger.com/go/NC/district/00135/search.aspx',
#    'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=00135'},
#   'county': {'countyName': 'Mecklenburg',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#   'rankHistory': None,
#   'rankMovement': None,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2017,
#     'numberOfStudents': 1371,
#     'percentFreeDiscLunch': None,
#     'percentofAfricanAmericanStudents': 4.23,
#     'percentofAsianStudents': 1.97,
#     'percentofHispanicStudents': 4.08,
#     'percentofIndianStudents': 0.22,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 86.07,
#     'percentofTwoOrMoreRaceStudents': 3.43,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 92.4,
#     'pupilTeacherRatio': 14.8,
#     'numberofAfricanAmericanStudents': 58,
#     'numberofAsianStudents': 27,
#     'numberofHispanicStudents': 56,
#     'numberofIndianStudents': 3,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 1180,
#     'numberofTwoOrMoreRaceStudents': 47,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': 2016,
#     'numberOfStudents': 1342,
#     'percentFreeDiscLunch': 0.0,
#     'percentofAfricanAmericanStudents': 4.17,
#     'percentofAsianStudents': 1.64,
#     'percentofHispanicStudents': 3.8,
#     'percentofIndianStudents': 0.22,
#     'percentofPacificIslanderStudents': 0.07,
#     'percentofWhiteStudents': 86.74,
#     'percentofTwoOrMoreRaceStudents': 3.35,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 82.0,
#     'pupilTeacherRatio': 16.3,
#     'numberofAfricanAmericanStudents': 56,
#     'numberofAsianStudents': 22,
#     'numberofHispanicStudents': 51,
#     'numberofIndianStudents': 3,
#     'numberofPacificIslanderStudents': 1,
#     'numberofWhiteStudents': 1164,
#     'numberofTwoOrMoreRaceStudents': 45,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': False,
#   'privateDays': None,
#   'privateHours': None,
#   'privateHasLibrary': None,
#   'privateCoed': None,
#   'privateOrientation': None,
#   'hasBoundary': False},
#  {'schoolid': '379999924942',
#   'schoolName': 'Davidson Day School',
#   'phone': '(704) 237-5220',
#   'url': 'https://www.schooldigger.com/go/NC/schools/9999924942/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/9999924942/search.aspx',
#   'address': {'latLong': {'latitude': 35.503543, 'longitude': -80.860489},
#    'street': '750 Jetton St',
#    'city': 'Davidson',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28036',
#    'zip4': '',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Davidson/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28036/search.aspx',
#    'html': '750 Jetton St<br />Davidson, NC 28036'},
#   'lowGrade': 'PK',
#   'highGrade': '12',
#   'schoolLevel': 'Private',
#   'isCharterSchool': '(n/a)',
#   'isMagnetSchool': '(n/a)',
#   'isVirtualSchool': '(n/a)',
#   'isTitleISchool': '(n/a)',
#   'isTitleISchoolwideSchool': '(n/a)',
#   'county': {'countyName': 'Mecklenburg',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#   'rankHistory': None,
#   'rankMovement': None,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2018,
#     'numberOfStudents': 516,
#     'percentFreeDiscLunch': None,
#     'percentofAfricanAmericanStudents': 3.68,
#     'percentofAsianStudents': 1.94,
#     'percentofHispanicStudents': 1.74,
#     'percentofIndianStudents': 0.39,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 82.75,
#     'percentofTwoOrMoreRaceStudents': 1.16,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 65.4,
#     'pupilTeacherRatio': 7.2,
#     'numberofAfricanAmericanStudents': 19,
#     'numberofAsianStudents': 10,
#     'numberofHispanicStudents': 9,
#     'numberofIndianStudents': 2,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 427,
#     'numberofTwoOrMoreRaceStudents': 6,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': 2016,
#     'numberOfStudents': 531,
#     'percentFreeDiscLunch': None,
#     'percentofAfricanAmericanStudents': 7.16,
#     'percentofAsianStudents': 2.26,
#     'percentofHispanicStudents': 1.88,
#     'percentofIndianStudents': 0.75,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 78.91,
#     'percentofTwoOrMoreRaceStudents': 0.19,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 51.6,
#     'pupilTeacherRatio': 9.3,
#     'numberofAfricanAmericanStudents': 38,
#     'numberofAsianStudents': 12,
#     'numberofHispanicStudents': 10,
#     'numberofIndianStudents': 4,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 419,
#     'numberofTwoOrMoreRaceStudents': 1,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': True,
#   'privateDays': 173,
#   'privateHours': 7.4,
#   'privateHasLibrary': True,
#   'privateCoed': 'Coed',
#   'privateOrientation': 'Nonsectarian',
#   'hasBoundary': False},
#  {'schoolid': '370297001208',
#   'schoolName': 'Davidson Elementary',
#   'phone': '(980) 343-3900',
#   'url': 'https://www.schooldigger.com/go/NC/schools/0297001208/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/0297001208/search.aspx',
#   'address': {'latLong': {'latitude': 35.489791, 'longitude': -80.8484},
#    'street': '635 South St',
#    'city': 'Davidson',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28036',
#    'zip4': '',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Davidson/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28036/search.aspx',
#    'html': '635 South St<br />Davidson, NC 28036'},
#   'lowGrade': 'K',
#   'highGrade': '5',
#   'schoolLevel': 'Elementary',
#   'isCharterSchool': 'No',
#   'isMagnetSchool': 'No',
#   'isVirtualSchool': 'No',
#   'isTitleISchool': 'No',
#   'isTitleISchoolwideSchool': 'No',
#   'district': {'districtID': '3702970',
#    'districtName': 'Charlotte-Mecklenburg Schools',
#    'url': 'https://www.schooldigger.com/go/NC/district/02970/search.aspx',
#    'rankURL': 'https://www.schooldigger.com/go/NC/districtrank.aspx?finddistrict=02970'},
#   'county': {'countyName': 'Mecklenburg',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#   'rankHistory': [{'year': 2019,
#     'rank': 82,
#     'rankOf': 1461,
#     'rankStars': 5,
#     'rankLevel': 'Elementary',
#     'rankStatewidePercentage': 94.39,
#     'averageStandardScore': 91.07875},
#    {'year': 2018,
#     'rank': 138,
#     'rankOf': 1434,
#     'rankStars': 5,
#     'rankLevel': 'Elementary',
#     'rankStatewidePercentage': 90.38,
#     'averageStandardScore': 86.85336}],
#   'rankMovement': 56,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2017,
#     'numberOfStudents': 708,
#     'percentFreeDiscLunch': 15.82,
#     'percentofAfricanAmericanStudents': 5.93,
#     'percentofAsianStudents': 2.26,
#     'percentofHispanicStudents': 11.3,
#     'percentofIndianStudents': 0.28,
#     'percentofPacificIslanderStudents': 0.42,
#     'percentofWhiteStudents': 78.67,
#     'percentofTwoOrMoreRaceStudents': 1.13,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 39.9,
#     'pupilTeacherRatio': 17.7,
#     'numberofAfricanAmericanStudents': 42,
#     'numberofAsianStudents': 16,
#     'numberofHispanicStudents': 80,
#     'numberofIndianStudents': 2,
#     'numberofPacificIslanderStudents': 3,
#     'numberofWhiteStudents': 557,
#     'numberofTwoOrMoreRaceStudents': 8,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': 2016,
#     'numberOfStudents': 708,
#     'percentFreeDiscLunch': 14.83,
#     'percentofAfricanAmericanStudents': 5.79,
#     'percentofAsianStudents': 2.26,
#     'percentofHispanicStudents': 11.72,
#     'percentofIndianStudents': 0.14,
#     'percentofPacificIslanderStudents': 0.28,
#     'percentofWhiteStudents': 78.95,
#     'percentofTwoOrMoreRaceStudents': 0.85,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 36.0,
#     'pupilTeacherRatio': 19.6,
#     'numberofAfricanAmericanStudents': 41,
#     'numberofAsianStudents': 16,
#     'numberofHispanicStudents': 83,
#     'numberofIndianStudents': 1,
#     'numberofPacificIslanderStudents': 2,
#     'numberofWhiteStudents': 559,
#     'numberofTwoOrMoreRaceStudents': 6,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': False,
#   'privateDays': None,
#   'privateHours': None,
#   'privateHasLibrary': None,
#   'privateCoed': None,
#   'privateOrientation': None,
#   'hasBoundary': True},
#  {'schoolid': '379999950673',
#   'schoolName': 'Davidson Green School',
#   'phone': '(704) 892-0091',
#   'url': 'https://www.schooldigger.com/go/NC/schools/9999950673/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/9999950673/search.aspx',
#   'address': {'latLong': {'latitude': 35.492887, 'longitude': -80.854384},
#    'street': '511 S Main St',
#    'city': 'Davidson',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28036',
#    'zip4': '',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Davidson/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28036/search.aspx',
#    'html': '511 S Main St<br />Davidson, NC 28036'},
#   'lowGrade': 'K',
#   'highGrade': '7',
#   'schoolLevel': 'Private',
#   'isCharterSchool': '(n/a)',
#   'isMagnetSchool': '(n/a)',
#   'isVirtualSchool': '(n/a)',
#   'isTitleISchool': '(n/a)',
#   'isTitleISchoolwideSchool': '(n/a)',
#   'county': {'countyName': 'Mecklenburg',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#   'rankHistory': None,
#   'rankMovement': None,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2018,
#     'numberOfStudents': 39,
#     'percentFreeDiscLunch': None,
#     'percentofAfricanAmericanStudents': 0.0,
#     'percentofAsianStudents': 0.0,
#     'percentofHispanicStudents': 0.0,
#     'percentofIndianStudents': 0.0,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 0.0,
#     'percentofTwoOrMoreRaceStudents': 0.0,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 6.1,
#     'pupilTeacherRatio': 6.3,
#     'numberofAfricanAmericanStudents': 0,
#     'numberofAsianStudents': 0,
#     'numberofHispanicStudents': 0,
#     'numberofIndianStudents': 0,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 0,
#     'numberofTwoOrMoreRaceStudents': 0,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': None,
#     'numberOfStudents': None,
#     'percentFreeDiscLunch': None,
#     'percentofAfricanAmericanStudents': None,
#     'percentofAsianStudents': None,
#     'percentofHispanicStudents': None,
#     'percentofIndianStudents': None,
#     'percentofPacificIslanderStudents': None,
#     'percentofWhiteStudents': None,
#     'percentofTwoOrMoreRaceStudents': None,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': None,
#     'pupilTeacherRatio': None,
#     'numberofAfricanAmericanStudents': None,
#     'numberofAsianStudents': None,
#     'numberofHispanicStudents': None,
#     'numberofIndianStudents': None,
#     'numberofPacificIslanderStudents': None,
#     'numberofWhiteStudents': None,
#     'numberofTwoOrMoreRaceStudents': None,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': True,
#   'privateDays': 180,
#   'privateHours': 7.0,
#   'privateHasLibrary': True,
#   'privateCoed': 'Coed',
#   'privateOrientation': 'Nonsectarian',
#   'hasBoundary': None},
#  {'schoolid': '379999937359',
#   'schoolName': 'Lake Norman Christian School',
#   'phone': '(704) 987-9811',
#   'url': 'https://www.schooldigger.com/go/NC/schools/9999937359/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/9999937359/search.aspx',
#   'address': {'latLong': {'latitude': 35.496126, 'longitude': -80.848806},
#    'street': '251 S St',
#    'city': 'Davidson',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28036',
#    'zip4': '',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Davidson/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28036/search.aspx',
#    'html': '251 S St<br />Davidson, NC 28036'},
#   'lowGrade': 'K',
#   'highGrade': '12',
#   'schoolLevel': 'Private',
#   'isCharterSchool': '(n/a)',
#   'isMagnetSchool': '(n/a)',
#   'isVirtualSchool': '(n/a)',
#   'isTitleISchool': '(n/a)',
#   'isTitleISchoolwideSchool': '(n/a)',
#   'county': {'countyName': 'Mecklenburg',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Mecklenburg/search.aspx'},
#   'rankHistory': None,
#   'rankMovement': None,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2018,
#     'numberOfStudents': 141,
#     'percentFreeDiscLunch': None,
#     'percentofAfricanAmericanStudents': 3.55,
#     'percentofAsianStudents': 1.42,
#     'percentofHispanicStudents': 12.77,
#     'percentofIndianStudents': 2.13,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 78.01,
#     'percentofTwoOrMoreRaceStudents': 2.13,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 18.9,
#     'pupilTeacherRatio': 7.4,
#     'numberofAfricanAmericanStudents': 5,
#     'numberofAsianStudents': 2,
#     'numberofHispanicStudents': 18,
#     'numberofIndianStudents': 3,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 110,
#     'numberofTwoOrMoreRaceStudents': 3,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': 2016,
#     'numberOfStudents': 138,
#     'percentFreeDiscLunch': None,
#     'percentofAfricanAmericanStudents': 2.9,
#     'percentofAsianStudents': 4.35,
#     'percentofHispanicStudents': 13.04,
#     'percentofIndianStudents': 0.0,
#     'percentofPacificIslanderStudents': 0.72,
#     'percentofWhiteStudents': 76.81,
#     'percentofTwoOrMoreRaceStudents': 2.17,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 17.6,
#     'pupilTeacherRatio': 7.8,
#     'numberofAfricanAmericanStudents': 4,
#     'numberofAsianStudents': 6,
#     'numberofHispanicStudents': 18,
#     'numberofIndianStudents': 0,
#     'numberofPacificIslanderStudents': 1,
#     'numberofWhiteStudents': 106,
#     'numberofTwoOrMoreRaceStudents': 3,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': True,
#   'privateDays': 178,
#   'privateHours': 7.0,
#   'privateHasLibrary': True,
#   'privateCoed': 'Coed',
#   'privateOrientation': 'Christian (no specific denomination)',
#   'hasBoundary': False},
#  {'schoolid': '379999933916',
#   'schoolName': 'Woodlawn School',
#   'phone': '(704) 895-8653',
#   'url': 'https://www.schooldigger.com/go/NC/schools/9999933916/school.aspx',
#   'urlCompare': 'https://www.schooldigger.com/go/NC/schools/9999933916/search.aspx',
#   'address': {'latLong': {'latitude': None, 'longitude': None},
#    'street': 'PO Box 549',
#    'city': 'Davidson',
#    'state': 'NC',
#    'stateFull': 'North Carolina',
#    'zip': '28036',
#    'zip4': '',
#    'cityURL': 'https://www.schooldigger.com/go/NC/city/Davidson/search.aspx',
#    'zipURL': 'https://www.schooldigger.com/go/NC/zip/28036/search.aspx',
#    'html': 'PO Box 549<br />Davidson, NC 28036'},
#   'lowGrade': 'K',
#   'highGrade': '12',
#   'schoolLevel': 'Private',
#   'isCharterSchool': '(n/a)',
#   'isMagnetSchool': '(n/a)',
#   'isVirtualSchool': '(n/a)',
#   'isTitleISchool': '(n/a)',
#   'isTitleISchoolwideSchool': '(n/a)',
#   'county': {'countyName': 'Iredell',
#    'countyURL': 'https://www.schooldigger.com/go/NC/county/Iredell/search.aspx'},
#   'rankHistory': None,
#   'rankMovement': None,
#   'locationIsWithinBoundary': None,
#   'schoolYearlyDetails': [{'year': 2018,
#     'numberOfStudents': 212,
#     'percentFreeDiscLunch': None,
#     'percentofAfricanAmericanStudents': 5.19,
#     'percentofAsianStudents': 3.3,
#     'percentofHispanicStudents': 4.72,
#     'percentofIndianStudents': 0.0,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 86.79,
#     'percentofTwoOrMoreRaceStudents': 0.0,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 27.9,
#     'pupilTeacherRatio': 7.5,
#     'numberofAfricanAmericanStudents': 11,
#     'numberofAsianStudents': 7,
#     'numberofHispanicStudents': 10,
#     'numberofIndianStudents': 0,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 184,
#     'numberofTwoOrMoreRaceStudents': 0,
#     'numberofUnspecifiedRaceStudents': None},
#    {'year': 2016,
#     'numberOfStudents': 197,
#     'percentFreeDiscLunch': None,
#     'percentofAfricanAmericanStudents': 1.52,
#     'percentofAsianStudents': 2.03,
#     'percentofHispanicStudents': 3.55,
#     'percentofIndianStudents': 0.0,
#     'percentofPacificIslanderStudents': 0.0,
#     'percentofWhiteStudents': 90.86,
#     'percentofTwoOrMoreRaceStudents': 2.03,
#     'percentofUnspecifiedRaceStudents': None,
#     'teachersFulltime': 27.1,
#     'pupilTeacherRatio': 7.2,
#     'numberofAfricanAmericanStudents': 3,
#     'numberofAsianStudents': 4,
#     'numberofHispanicStudents': 7,
#     'numberofIndianStudents': 0,
#     'numberofPacificIslanderStudents': 0,
#     'numberofWhiteStudents': 179,
#     'numberofTwoOrMoreRaceStudents': 4,
#     'numberofUnspecifiedRaceStudents': None}],
#   'isPrivate': True,
#   'privateDays': 177,
#   'privateHours': 7.0,
#   'privateHasLibrary': False,
#   'privateCoed': 'Coed',
#   'privateOrientation': 'Nonsectarian',
#   'hasBoundary': False}]

# %%
school_dict = [] 

# Loop through all the cities in our list
for school in range(len(schoolList)):
    #response = requests.get(url, verify = verify).json() # Api call
    school_lng = schoolList[school]["address"]["latLong"]["longitude"]
    school_lat = schoolList[school]["address"]["latLong"]["latitude"]
    school_names = schoolList[school]["schoolName"]
    school_street = schoolList[school]["address"]["street"]
    school_states = schoolList[school]["address"]["state"]
    school_city = schoolList[school]["address"]["city"]
    school_county = schoolList[school]["county"]["countyName"]
    school_zip = schoolList[school]["address"]["zip"]
    school_level = schoolList[school]["schoolLevel"]
    school_year = schoolList[school]["schoolYearlyDetails"][0]["year"]
    students_number = schoolList[school]["schoolYearlyDetails"][0]["numberOfStudents"]
        
    school_dict.append({
        "schoolName": school_names,
        "street": school_street,
        "zip": school_zip,
        "state": school_states,
        "city": school_city,
        "countyName": school_county,
        "schoolYear" : school_year,
        "schoolLevel": school_level,
        "longitude": school_lng,
        "latitude": school_lat,
        "studentsNumber": students_number
    })
        
Davidson_data = pd.DataFrame(school_dict)
Davidson_data
# Out:
#        city   countyName   latitude  longitude schoolLevel  \
# 0  Davidson  Mecklenburg  35.501804 -80.859593       Other
# 1  Davidson  Mecklenburg  35.503543 -80.860489     Private
# 2  Davidson  Mecklenburg  35.489791 -80.848400  Elementary
# 3  Davidson  Mecklenburg  35.492887 -80.854384     Private
# 4  Davidson  Mecklenburg  35.496126 -80.848806     Private
# 5  Davidson      Iredell        NaN        NaN     Private
#
#                      schoolName  schoolYear state             street  \
# 0  Community School of Davidson        2017    NC  404 Armour Street
# 1           Davidson Day School        2018    NC      750 Jetton St
# 2           Davidson Elementary        2017    NC       635 South St
# 3         Davidson Green School        2018    NC      511 S Main St
# 4  Lake Norman Christian School        2018    NC           251 S St
# 5               Woodlawn School        2018    NC         PO Box 549
#
#    studentsNumber    zip
# 0            1371  28036
# 1             516  28036
# 2             708  28036
# 3              39  28036
# 4             141  28036
# 5             212  28036

# %%
Davidson_data.to_csv("Davidson_data.csv", index=False)
